# %% [markdown]
# <a href="https://colab.research.google.com/github/MoustHolmes/AMAS_Project/blob/Aske/DDPG_RaceTrack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installs

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Out:
# Requirement already satisfied: box2d-py in /usr/local/lib/python3.7/dist-packages (2.3.8)

# %% [markdown]
# # Imports

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import scipy.linalg
import gym
from gym import spaces, logger
from gym.utils import seeding

import os
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# # Enviroment

# %% [markdown]
# # Networks

# %%
# model_save_name = 'classifier.pt'
# path = F"/content/gdrive/My Drive/{model_save_name}" 
# torch.save(model.state_dict(), path)

# %%
class CriticNetwork(nn.Module):
    def __init__(self, beta, input_dims, fc1_dims, fc2_dims, n_actions, name,
                 chkpt_dir='/content/gdrive/My Drive'):
        super(CriticNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.name = name
        model_save_name = name + '_2.pt'
        # self.path = F"/content/gdrive/My Drive/{model_save_name}" 
        self.checkpoint_dir = F"/content/gdrive/My Drive/{model_save_name}"
        # self.checkpoint_dir = chkpt_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_ddpg')

        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)

        self.bn1 = nn.LayerNorm(self.fc1_dims)
        self.bn2 = nn.LayerNorm(self.fc2_dims)
        #self.bn1 = nn.BatchNorm1d(self.fc1_dims)
        #self.bn2 = nn.BatchNorm1d(self.fc2_dims)

        self.action_value = nn.Linear(self.n_actions, self.fc2_dims)
        
        self.q = nn.Linear(self.fc2_dims, 1)

        f1 = 1./np.sqrt(self.fc1.weight.data.size()[0])
        self.fc1.weight.data.uniform_(-f1, f1)
        self.fc1.bias.data.uniform_(-f1, f1)

        f2 = 1./np.sqrt(self.fc2.weight.data.size()[0])
        self.fc2.weight.data.uniform_(-f2, f2)
        self.fc2.bias.data.uniform_(-f2, f2)

        f3 = 0.003
        self.q.weight.data.uniform_(-f3, f3)
        self.q.bias.data.uniform_(-f3, f3)

        f4 = 1./np.sqrt(self.action_value.weight.data.size()[0])
        
        self.action_value.weight.data.uniform_(-f4, f4)
        self.action_value.bias.data.uniform_(-f4, f4)

        self.optimizer = optim.Adam(self.parameters(), lr=beta,
                                    weight_decay=0.01)
        
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cuda:1')

        self.to(self.device)

    def forward(self, state, action):
        state_value = self.fc1(state)
        state_value = self.bn1(state_value)
        state_value = F.relu(state_value)
        state_value = self.fc2(state_value)
        state_value = self.bn2(state_value)
        #state_value = F.relu(state_value)
        #action_value = F.relu(self.action_value(action))
        action_value = self.action_value(action)
        state_action_value = F.relu(T.add(state_value, action_value))
        #state_action_value = T.add(state_value, action_value)
        state_action_value = self.q(state_action_value)

        return state_action_value

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        # T.save(self.state_dict(), self.path)
        # T.save(self.state_dict(), self.checkpoint_file)
        T.save(self.state_dict(), self.checkpoint_dir)

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_dir))

    def save_best(self):
        print('... saving best checkpoint ...')
        checkpoint_file = os.path.join(self.checkpoint_dir, self.name+'_best')
        T.save(self.state_dict(), checkpoint_file)

class ActorNetwork(nn.Module):
    def __init__(self, alpha, input_dims, fc1_dims, fc2_dims, n_actions, name,
                 chkpt_dir='/content/gdrive/My Drive'):
        super(ActorNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.name = name
        model_save_name = name + '_2.pt'
        # self.path = F"/content/gdrive/My Drive/{model_save_name}" 
        self.checkpoint_dir = F"/content/gdrive/My Drive/{model_save_name}"
        # self.checkpoint_dir = chkpt_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_ddpg')

        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)

        self.bn1 = nn.LayerNorm(self.fc1_dims)
        self.bn2 = nn.LayerNorm(self.fc2_dims)

        #self.bn1 = nn.BatchNorm1d(self.fc1_dims)
        #self.bn2 = nn.BatchNorm1d(self.fc2_dims)

        self.mu = nn.Linear(self.fc2_dims, self.n_actions)

        f2 = 1./np.sqrt(self.fc2.weight.data.size()[0])
        self.fc2.weight.data.uniform_(-f2, f2)
        self.fc2.bias.data.uniform_(-f2, f2)

        f1 = 1./np.sqrt(self.fc1.weight.data.size()[0])
        self.fc1.weight.data.uniform_(-f1, f1)
        self.fc1.bias.data.uniform_(-f1, f1)

        f3 = 0.003
        self.mu.weight.data.uniform_(-f3, f3)
        self.mu.bias.data.uniform_(-f3, f3)

        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cuda:1')

        self.to(self.device)

    def forward(self, state):
        x = self.fc1(state)
        x = self.bn1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = T.tanh(self.mu(x))

        return x

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        # T.save(self.state_dict(), self.checkpoint_file)
        T.save(self.state_dict(), self.checkpoint_dir)#changed file to dir 

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_dir))#changed file to dir

    def save_best(self):
        print('... saving best checkpoint ...')
        checkpoint_file = os.path.join(self.checkpoint_dir, self.name+'_best')
        T.save(self.state_dict(), checkpoint_file)

# %% [markdown]
# # Noise

# %%
class OUActionNoise():
    def __init__(self, mu, sigma=0.15, theta=0.2, dt=1e-2, x0=None):
        self.theta = theta
        self.mu = mu
        self.sigma = sigma
        self.dt = dt
        self.x0 = x0
        self.reset()

    def __call__(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + self.sigma * np.sqrt(self.dt) * np.random.normal(size=self.mu.shape)
        self.x_prev = x
        return x

    def reset(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros_like(self.mu)

# %% [markdown]
# #Replay Buffer

# %%
class ReplayBuffer():
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_shape))
        self.new_state_memory = np.zeros((self.mem_size, *input_shape))
        self.action_memory = np.zeros((self.mem_size, n_actions))
        self.reward_memory = np.zeros(self.mem_size)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)

    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.new_state_memory[index] = state_
        self.terminal_memory[index] = done

        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)

        batch = np.random.choice(max_mem, batch_size)

        states = self.state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        states_ = self.new_state_memory[batch]
        dones = self.terminal_memory[batch]

        return states, actions, rewards, states_, dones

# %% [markdown]
# # Agent
#
# note that i can outcomment the setting the terminal flag to zero if the reward scheme only gives negative rewards

# %%
class Agent():
    def __init__(self, alpha, beta, input_dims, tau, n_actions, output_bounds, gamma=0.99,
                 max_size=1000000, fc1_dims=400, fc2_dims=300, 
                 batch_size=256,
                 noise_sigma = 0.15):
      #output bounds are my addition 
        self.output_bounds = output_bounds
        self.gamma = gamma
        self.tau = tau
        self.batch_size = batch_size
        self.alpha = alpha
        self.beta = beta
        # self.noise_sigma = noise_sigma

        self.memory = ReplayBuffer(max_size, input_dims, n_actions)
        #we have  to scale the noise to match the outpu bounds

        var_names = str(alpha) +'_'+ str(beta) +'_'+ str(gamma) +'_' +str(fc1_dims) +'_'+ str(fc2_dims) +'_'+ str(noise_sigma)

        self.noise = OUActionNoise(mu=np.zeros(n_actions), sigma = noise_sigma *output_bounds)

        self.actor = ActorNetwork(alpha, input_dims, fc1_dims, fc2_dims,
                                n_actions=n_actions, name='actor' +var_names)
        self.critic = CriticNetwork(beta, input_dims, fc1_dims, fc2_dims,
                                n_actions=n_actions, name='critic' +var_names)

        self.target_actor = ActorNetwork(alpha, input_dims, fc1_dims, fc2_dims,
                                n_actions=n_actions, name='target_actor' +var_names)

        self.target_critic = CriticNetwork(beta, input_dims, fc1_dims, fc2_dims,
                                n_actions=n_actions, name='target_critic' +var_names)

        self.update_network_parameters(tau=1)

    def choose_action(self, observation):
        self.actor.eval()
        state = T.tensor([observation], dtype=T.float).to(self.actor.device)
        mu = self.actor.forward(state).to(self.actor.device)
        mu_prime = mu + T.tensor(self.noise(), 
                                    dtype=T.float).to(self.actor.device)
        self.actor.train()

        return mu_prime.cpu().detach().numpy()[0]*self.output_bounds

    def choose_action_no_noise(self, observation):#my addition
        self.actor.eval()
        state = T.tensor([observation], dtype=T.float).to(self.actor.device)
        mu = self.actor.forward(state).to(self.actor.device)
        return mu.cpu().detach().numpy()[0]*self.output_bounds

    def choose_action_no_noise_batch(self, observation):#my addition
        self.actor.eval()
        state = T.tensor(observation, dtype=T.float).to(self.actor.device)
        mu = self.actor.forward(state)#.to(self.actor.device)
        return mu.cpu().detach().numpy()*self.output_bounds

    def remember(self, state, action, reward, state_, done):
        self.memory.store_transition(state, action, reward, state_, done)

    def save_models(self):
        self.actor.save_checkpoint()
        self.target_actor.save_checkpoint()
        self.critic.save_checkpoint()
        self.target_critic.save_checkpoint()

    def load_models(self):
        self.actor.load_checkpoint()
        self.target_actor.load_checkpoint()
        self.critic.load_checkpoint()
        self.target_critic.load_checkpoint()

    def learn(self):
        if self.memory.mem_cntr < self.batch_size:
            return

        states, actions, rewards, states_, done = \
                self.memory.sample_buffer(self.batch_size)

        states = T.tensor(states, dtype=T.float).to(self.actor.device)
        states_ = T.tensor(states_, dtype=T.float).to(self.actor.device)
        actions = T.tensor(actions, dtype=T.float).to(self.actor.device)
        rewards = T.tensor(rewards, dtype=T.float).to(self.actor.device)
        done = T.tensor(done).to(self.actor.device)

        target_actions = self.target_actor.forward(states_)
        critic_value_ = self.target_critic.forward(states_, target_actions)
        critic_value = self.critic.forward(states, actions)

        critic_value_[done] = 0.0
        critic_value_ = critic_value_.view(-1)

        target = rewards + self.gamma*critic_value_
        target = target.view(self.batch_size, 1)

        self.critic.optimizer.zero_grad()
        critic_loss = F.mse_loss(target, critic_value)
        critic_loss.backward()
        self.critic.optimizer.step()

        self.actor.optimizer.zero_grad()
        actor_loss = -self.critic.forward(states, self.actor.forward(states))
        actor_loss = T.mean(actor_loss)
        actor_loss.backward()
        self.actor.optimizer.step()

        self.update_network_parameters()

    def update_network_parameters(self, tau=None):
        if tau is None:
            tau = self.tau

        actor_params = self.actor.named_parameters()
        critic_params = self.critic.named_parameters()
        target_actor_params = self.target_actor.named_parameters()
        target_critic_params = self.target_critic.named_parameters()

        critic_state_dict = dict(critic_params)
        actor_state_dict = dict(actor_params)
        target_critic_state_dict = dict(target_critic_params)
        target_actor_state_dict = dict(target_actor_params)

        for name in critic_state_dict:
            critic_state_dict[name] = tau*critic_state_dict[name].clone() + \
                                (1-tau)*target_critic_state_dict[name].clone()

        for name in actor_state_dict:
             actor_state_dict[name] = tau*actor_state_dict[name].clone() + \
                                 (1-tau)*target_actor_state_dict[name].clone()

        self.target_critic.load_state_dict(critic_state_dict)
        self.target_actor.load_state_dict(actor_state_dict)
        #self.target_critic.load_state_dict(critic_state_dict, strict=False)
        #self.target_actor.load_state_dict(actor_state_dict, strict=False)

# %% [markdown]
# # Utils

# %%
def plot_learning_curve(x, scores, figure_file):
    running_avg = np.zeros(len(scores))
    for i in range(len(running_avg)):
        running_avg[i] = np.mean(scores[max(0, i-100):(i+1)])
    plt.plot(x, running_avg)
    plt.title('Running average of previous 100 scores')
    plt.savefig(figure_file)

# %%
env = gym.make('LunarLander-v2')

# %% [markdown]
# # Main

# %%
# env = CartPoleEnv(use_theta_threshold=True)

env = gym.make('LunarLanderContinuous-v2')
agent = Agent(alpha=0.000025, beta=0.00025, 
                input_dims=env.observation_space.shape, output_bounds=1,
                tau=0.001,
                batch_size=64, fc1_dims=400, fc2_dims=300, 
                n_actions=4)
# agent.load_models()
n_games = 15000

n_steps=200

filename = 'Cartpole_DDPG_alpha_' + str(agent.alpha) + '_beta_' + \
            str(agent.beta) + '_' + str(n_games) + '_games'
figure_file =  filename + '.png'

best_score = env.reward_range[0]
score_history = []
score_action_history = []

# %%
# agent.load_models()
n_games=20000
for i in range(n_games):
    observation = env.reset()
    # print(observation.shape)
    # print(observation)
    done = False
    score = 0
    agent.noise.reset()
    k=0
    while not done:
        # env.render()
        k+=1
        
        action = agent.choose_action(observation)

        # print(action)
        observation_, reward, done, info = env.step(action)
        # print(observation_.shape) 
        # print(observation_)
        agent.remember(observation, action, reward, observation_, done)
        agent.learn()
        score += reward
        observation = observation_
        if k>n_steps:
            done=True
    score_history.append(score)
    score_action_history.append(score/k)
    
    avg_score = np.mean(score_history[-100:])
    avg_action_score = np.mean(score_action_history[-100:])

    if avg_score > best_score and i > 80:
        best_score = avg_score
        # agent.save_models()

    print('episode ', i, 'score %.1f' % score,'episode length ',k,
            'average score %.1f' % avg_score, 'best score:%.1f' %best_score)
    
    # if avg_action_score > best_score and i > 30:
    #     best_score = avg_action_score
    #     agent.save_models()
    
    # print('episode ', i, 'score %.1f' % score_action_history[-1],'episode length ',k,
    #         'average score %.1f' % avg_action_score)
# env.close() 
# x = [i+1 for i in range(len((score_history))]
# plot_learning_curve(x, score_history, figure_file)
# Out:
# Streaming af output blev afkortet til de sidste 5000 linjer.
# episode  1862 score 116.5 episode length  201 average score 100.2 best score:109.3
# episode  1863 score 115.5 episode length  201 average score 100.3 best score:109.3
# episode  1864 score 102.3 episode length  201 average score 100.4 best score:109.3
# episode  1865 score 98.1 episode length  201 average score 100.7 best score:109.3
# episode  1866 score 141.1 episode length  201 average score 101.1 best score:109.3
# episode  1867 score 115.4 episode length  201 average score 101.1 best score:109.3
# episode  1868 score 132.4 episode length  201 average score 101.1 best score:109.3
# episode  1869 score 121.3 episode length  201 average score 101.4 best score:109.3
# episode  1870 score 35.5 episode length  201 average score 100.3 best score:109.3
# episode  1871 score 125.8 episode length  201 average score 100.9 best score:109.3
# episode  1872 score 125.7 episode length  201 average score 101.3 best score:109.3
# episode  1873 score 126.2 episode length  201 average score 101.4 best score:109.3
# episode  1874 score 70.7 episode length  201 average score 101.5 best score:109.3
# episode  1875 score 98.2 episode length  201 average score 101.2 best score:109.3
# episode  1876 score 128.4 episode length  201 average score 101.5 best score:109.3
# episode  1877 score 117.1 episode length  201 average score 101.8 best score:109.3
# episode  1878 score 84.6 episode length  201 average score 101.5 best score:109.3
# episode  1879 score 103.5 episode length  201 average score 101.0 best score:109.3
# episode  1880 score 121.3 episode length  201 average score 101.3 best score:109.3
# episode  1881 score -231.0 episode length  178 average score 98.0 best score:109.3
# episode  1882 score 103.9 episode length  201 average score 98.1 best score:109.3
# episode  1883 score 111.2 episode length  201 average score 97.8 best score:109.3
# episode  1884 score 96.8 episode length  201 average score 97.7 best score:109.3
# episode  1885 score 102.2 episode length  201 average score 97.9 best score:109.3
# episode  1886 score 92.5 episode length  201 average score 97.8 best score:109.3
# episode  1887 score 93.9 episode length  201 average score 97.6 best score:109.3
# episode  1888 score 90.4 episode length  201 average score 97.2 best score:109.3
# episode  1889 score 88.1 episode length  201 average score 97.0 best score:109.3
# episode  1890 score 116.2 episode length  201 average score 97.0 best score:109.3
# episode  1891 score 103.6 episode length  201 average score 97.0 best score:109.3
# episode  1892 score 111.6 episode length  201 average score 97.0 best score:109.3
# episode  1893 score 106.8 episode length  201 average score 96.7 best score:109.3
# episode  1894 score 121.3 episode length  201 average score 96.8 best score:109.3
# episode  1895 score 165.8 episode length  201 average score 97.5 best score:109.3
# episode  1896 score 137.1 episode length  201 average score 97.6 best score:109.3
# episode  1897 score 128.6 episode length  201 average score 97.7 best score:109.3
# episode  1898 score 92.5 episode length  201 average score 97.9 best score:109.3
# episode  1899 score 94.6 episode length  201 average score 97.6 best score:109.3
# episode  1900 score 165.9 episode length  201 average score 98.2 best score:109.3
# episode  1901 score 104.7 episode length  201 average score 98.1 best score:109.3
# episode  1902 score 127.9 episode length  201 average score 98.1 best score:109.3
# episode  1903 score 112.7 episode length  201 average score 98.2 best score:109.3
# episode  1904 score 100.2 episode length  201 average score 98.0 best score:109.3
# episode  1905 score 142.4 episode length  201 average score 98.2 best score:109.3
# episode  1906 score 129.2 episode length  201 average score 98.8 best score:109.3
# episode  1907 score 93.1 episode length  201 average score 98.7 best score:109.3
# episode  1908 score 133.1 episode length  201 average score 98.9 best score:109.3
# episode  1909 score -112.8 episode length  138 average score 97.9 best score:109.3
# episode  1910 score 64.2 episode length  201 average score 97.2 best score:109.3
# episode  1911 score 73.8 episode length  201 average score 97.1 best score:109.3
# episode  1912 score 66.6 episode length  201 average score 96.6 best score:109.3
# episode  1913 score 98.0 episode length  201 average score 97.7 best score:109.3
# episode  1914 score 143.3 episode length  201 average score 98.2 best score:109.3
# episode  1915 score 100.2 episode length  201 average score 98.5 best score:109.3
# episode  1916 score 127.2 episode length  201 average score 98.6 best score:109.3
# episode  1917 score 115.9 episode length  201 average score 98.7 best score:109.3
# episode  1918 score 34.5 episode length  201 average score 97.9 best score:109.3
# episode  1919 score 104.6 episode length  201 average score 98.3 best score:109.3
# episode  1920 score 117.9 episode length  201 average score 98.7 best score:109.3
# episode  1921 score 13.3 episode length  97 average score 97.6 best score:109.3
# episode  1922 score 104.7 episode length  201 average score 97.9 best score:109.3
# episode  1923 score 126.8 episode length  201 average score 98.3 best score:109.3
# episode  1924 score 111.2 episode length  201 average score 98.4 best score:109.3
# episode  1925 score 98.6 episode length  201 average score 98.5 best score:109.3
# episode  1926 score 95.3 episode length  201 average score 98.4 best score:109.3
# episode  1927 score 123.2 episode length  201 average score 98.6 best score:109.3
# episode  1928 score 83.5 episode length  201 average score 98.5 best score:109.3
# episode  1929 score 101.5 episode length  201 average score 98.4 best score:109.3
# episode  1930 score 116.0 episode length  201 average score 98.5 best score:109.3
# episode  1931 score 101.6 episode length  201 average score 98.5 best score:109.3
# episode  1932 score 111.4 episode length  201 average score 98.3 best score:109.3
# episode  1933 score 96.2 episode length  201 average score 98.2 best score:109.3
# episode  1934 score 109.9 episode length  201 average score 98.2 best score:109.3
# episode  1935 score 122.8 episode length  201 average score 98.3 best score:109.3
# episode  1936 score -185.7 episode length  154 average score 95.4 best score:109.3
# episode  1937 score 100.2 episode length  201 average score 95.6 best score:109.3
# episode  1938 score 121.0 episode length  201 average score 95.8 best score:109.3
# episode  1939 score 86.9 episode length  201 average score 96.2 best score:109.3
# episode  1940 score 103.7 episode length  201 average score 96.1 best score:109.3
# episode  1941 score 111.0 episode length  201 average score 96.2 best score:109.3
# episode  1942 score 98.5 episode length  201 average score 96.3 best score:109.3
# episode  1943 score 101.0 episode length  201 average score 96.1 best score:109.3
# episode  1944 score 93.6 episode length  201 average score 96.0 best score:109.3
# episode  1945 score 94.5 episode length  201 average score 96.0 best score:109.3
# episode  1946 score 84.0 episode length  201 average score 96.6 best score:109.3
# episode  1947 score 92.2 episode length  201 average score 96.6 best score:109.3
# episode  1948 score 134.8 episode length  201 average score 97.7 best score:109.3
# episode  1949 score 114.7 episode length  201 average score 98.1 best score:109.3
# episode  1950 score 67.8 episode length  201 average score 97.7 best score:109.3
# episode  1951 score 99.5 episode length  201 average score 98.0 best score:109.3
# episode  1952 score 34.1 episode length  201 average score 97.1 best score:109.3
# episode  1953 score 101.6 episode length  201 average score 96.9 best score:109.3
# episode  1954 score 108.6 episode length  201 average score 96.9 best score:109.3
# episode  1955 score 50.8 episode length  201 average score 96.2 best score:109.3
# episode  1956 score 90.8 episode length  201 average score 96.0 best score:109.3
# episode  1957 score 118.2 episode length  201 average score 96.0 best score:109.3
# episode  1958 score 103.0 episode length  201 average score 96.2 best score:109.3
# episode  1959 score 122.3 episode length  201 average score 96.1 best score:109.3
# episode  1960 score 111.4 episode length  201 average score 96.3 best score:109.3
# episode  1961 score 85.8 episode length  201 average score 96.1 best score:109.3
# episode  1962 score 114.3 episode length  201 average score 96.1 best score:109.3
# episode  1963 score 129.8 episode length  201 average score 96.2 best score:109.3
# episode  1964 score 22.7 episode length  115 average score 95.4 best score:109.3
# episode  1965 score 99.3 episode length  201 average score 95.4 best score:109.3
# episode  1966 score 103.1 episode length  201 average score 95.0 best score:109.3
# episode  1967 score 93.3 episode length  201 average score 94.8 best score:109.3
# episode  1968 score 118.6 episode length  201 average score 94.7 best score:109.3
# episode  1969 score 110.5 episode length  201 average score 94.6 best score:109.3
# episode  1970 score 110.3 episode length  201 average score 95.3 best score:109.3
# episode  1971 score 30.1 episode length  137 average score 94.4 best score:109.3
# episode  1972 score 36.0 episode length  157 average score 93.5 best score:109.3
# episode  1973 score 99.6 episode length  201 average score 93.2 best score:109.3
# episode  1974 score 116.5 episode length  201 average score 93.7 best score:109.3
# episode  1975 score 104.9 episode length  201 average score 93.7 best score:109.3
# episode  1976 score 83.6 episode length  201 average score 93.3 best score:109.3
# episode  1977 score 102.2 episode length  201 average score 93.1 best score:109.3
# episode  1978 score 118.5 episode length  201 average score 93.5 best score:109.3
# episode  1979 score 103.6 episode length  201 average score 93.5 best score:109.3
# episode  1980 score 14.8 episode length  128 average score 92.4 best score:109.3
# episode  1981 score 140.2 episode length  201 average score 96.1 best score:109.3
# episode  1982 score 295.4 episode length  188 average score 98.0 best score:109.3
# episode  1983 score 104.0 episode length  201 average score 98.0 best score:109.3
# episode  1984 score 36.3 episode length  79 average score 97.4 best score:109.3
# episode  1985 score 91.9 episode length  201 average score 97.3 best score:109.3
# episode  1986 score -9.4 episode length  92 average score 96.2 best score:109.3
# episode  1987 score 90.2 episode length  201 average score 96.2 best score:109.3
# episode  1988 score 132.3 episode length  201 average score 96.6 best score:109.3
# episode  1989 score 139.1 episode length  201 average score 97.1 best score:109.3
# episode  1990 score 38.8 episode length  129 average score 96.4 best score:109.3
# episode  1991 score 92.3 episode length  201 average score 96.2 best score:109.3
# episode  1992 score 92.7 episode length  201 average score 96.1 best score:109.3
# episode  1993 score 65.8 episode length  201 average score 95.6 best score:109.3
# episode  1994 score 96.3 episode length  201 average score 95.4 best score:109.3
# episode  1995 score -18.6 episode length  87 average score 93.5 best score:109.3
# episode  1996 score 113.2 episode length  201 average score 93.3 best score:109.3
# episode  1997 score 68.2 episode length  151 average score 92.7 best score:109.3
# episode  1998 score 86.4 episode length  201 average score 92.6 best score:109.3
# episode  1999 score 107.9 episode length  201 average score 92.8 best score:109.3
# episode  2000 score -18.6 episode length  194 average score 90.9 best score:109.3
# episode  2001 score 126.3 episode length  201 average score 91.1 best score:109.3
# episode  2002 score 131.4 episode length  201 average score 91.2 best score:109.3
# episode  2003 score 106.8 episode length  201 average score 91.1 best score:109.3
# episode  2004 score 44.9 episode length  201 average score 90.6 best score:109.3
# episode  2005 score 99.9 episode length  201 average score 90.1 best score:109.3
# episode  2006 score 107.9 episode length  201 average score 89.9 best score:109.3
# episode  2007 score 105.3 episode length  201 average score 90.1 best score:109.3
# episode  2008 score 100.3 episode length  201 average score 89.7 best score:109.3
# episode  2009 score 85.3 episode length  201 average score 91.7 best score:109.3
# episode  2010 score 82.7 episode length  201 average score 91.9 best score:109.3
# episode  2011 score 118.0 episode length  201 average score 92.3 best score:109.3
# episode  2012 score -10.6 episode length  163 average score 91.6 best score:109.3
# episode  2013 score 117.3 episode length  201 average score 91.8 best score:109.3
# episode  2014 score 135.0 episode length  201 average score 91.7 best score:109.3
# episode  2015 score 18.0 episode length  99 average score 90.9 best score:109.3
# episode  2016 score 110.9 episode length  201 average score 90.7 best score:109.3
# episode  2017 score 108.0 episode length  201 average score 90.6 best score:109.3
# episode  2018 score 87.6 episode length  201 average score 91.1 best score:109.3
# episode  2019 score 96.1 episode length  201 average score 91.1 best score:109.3
# episode  2020 score 115.8 episode length  201 average score 91.0 best score:109.3
# episode  2021 score 82.3 episode length  201 average score 91.7 best score:109.3
# episode  2022 score -119.5 episode length  87 average score 89.5 best score:109.3
# episode  2023 score 145.1 episode length  201 average score 89.7 best score:109.3
# episode  2024 score 101.0 episode length  201 average score 89.6 best score:109.3
# episode  2025 score 164.4 episode length  201 average score 90.2 best score:109.3
# episode  2026 score 148.6 episode length  201 average score 90.8 best score:109.3
# episode  2027 score 81.8 episode length  201 average score 90.3 best score:109.3
# episode  2028 score 65.6 episode length  201 average score 90.2 best score:109.3
# episode  2029 score 108.5 episode length  201 average score 90.2 best score:109.3
# episode  2030 score 96.4 episode length  201 average score 90.0 best score:109.3
# episode  2031 score 108.8 episode length  201 average score 90.1 best score:109.3
# episode  2032 score -67.9 episode length  64 average score 88.3 best score:109.3
# episode  2033 score 113.3 episode length  201 average score 88.5 best score:109.3
# episode  2034 score -137.7 episode length  75 average score 86.0 best score:109.3
# episode  2035 score 115.0 episode length  201 average score 85.9 best score:109.3
# episode  2036 score 111.4 episode length  201 average score 88.9 best score:109.3
# episode  2037 score 41.7 episode length  92 average score 88.3 best score:109.3
# episode  2038 score 128.1 episode length  201 average score 88.4 best score:109.3
# episode  2039 score -24.1 episode length  84 average score 87.3 best score:109.3
# episode  2040 score 119.4 episode length  201 average score 87.4 best score:109.3
# episode  2041 score 88.0 episode length  201 average score 87.2 best score:109.3
# episode  2042 score 97.9 episode length  201 average score 87.2 best score:109.3
# episode  2043 score 85.2 episode length  201 average score 87.0 best score:109.3
# episode  2044 score 12.6 episode length  97 average score 86.2 best score:109.3
# episode  2045 score 88.7 episode length  201 average score 86.2 best score:109.3
# episode  2046 score 106.5 episode length  201 average score 86.4 best score:109.3
# episode  2047 score 119.1 episode length  201 average score 86.7 best score:109.3
# episode  2048 score 95.6 episode length  201 average score 86.3 best score:109.3
# episode  2049 score 88.4 episode length  201 average score 86.0 best score:109.3
# episode  2050 score 93.5 episode length  201 average score 86.3 best score:109.3
# episode  2051 score 86.3 episode length  201 average score 86.1 best score:109.3
# episode  2052 score 104.3 episode length  201 average score 86.8 best score:109.3
# episode  2053 score 94.5 episode length  201 average score 86.8 best score:109.3
# episode  2054 score 102.6 episode length  201 average score 86.7 best score:109.3
# episode  2055 score 121.2 episode length  201 average score 87.4 best score:109.3
# episode  2056 score 84.7 episode length  201 average score 87.4 best score:109.3
# episode  2057 score 76.6 episode length  201 average score 86.9 best score:109.3
# episode  2058 score -34.2 episode length  88 average score 85.6 best score:109.3
# episode  2059 score 92.5 episode length  201 average score 85.3 best score:109.3
# episode  2060 score 135.6 episode length  201 average score 85.5 best score:109.3
# episode  2061 score 110.7 episode length  201 average score 85.8 best score:109.3
# episode  2062 score 115.7 episode length  201 average score 85.8 best score:109.3
# episode  2063 score 123.3 episode length  201 average score 85.7 best score:109.3
# episode  2064 score 107.6 episode length  201 average score 86.6 best score:109.3
# episode  2065 score 32.4 episode length  201 average score 85.9 best score:109.3
# episode  2066 score 89.1 episode length  201 average score 85.7 best score:109.3
# episode  2067 score 104.1 episode length  201 average score 85.9 best score:109.3
# episode  2068 score 63.6 episode length  201 average score 85.3 best score:109.3
# episode  2069 score 48.2 episode length  201 average score 84.7 best score:109.3
# episode  2070 score 102.6 episode length  201 average score 84.6 best score:109.3
# episode  2071 score 114.7 episode length  201 average score 85.4 best score:109.3
# episode  2072 score 104.8 episode length  201 average score 86.1 best score:109.3
# episode  2073 score 103.1 episode length  201 average score 86.2 best score:109.3
# episode  2074 score 94.7 episode length  201 average score 86.0 best score:109.3
# episode  2075 score 111.4 episode length  201 average score 86.0 best score:109.3
# episode  2076 score 91.0 episode length  201 average score 86.1 best score:109.3
# episode  2077 score 56.1 episode length  201 average score 85.6 best score:109.3
# episode  2078 score 109.2 episode length  201 average score 85.5 best score:109.3
# episode  2079 score 93.1 episode length  201 average score 85.4 best score:109.3
# episode  2080 score 88.0 episode length  201 average score 86.2 best score:109.3
# episode  2081 score 48.3 episode length  201 average score 85.2 best score:109.3
# episode  2082 score 78.6 episode length  201 average score 83.1 best score:109.3
# episode  2083 score 122.8 episode length  201 average score 83.3 best score:109.3
# episode  2084 score 116.2 episode length  201 average score 84.1 best score:109.3
# episode  2085 score 80.9 episode length  201 average score 84.0 best score:109.3
# episode  2086 score 87.8 episode length  201 average score 84.9 best score:109.3
# episode  2087 score 99.3 episode length  201 average score 85.0 best score:109.3
# episode  2088 score 118.5 episode length  201 average score 84.9 best score:109.3
# episode  2089 score 91.3 episode length  201 average score 84.4 best score:109.3
# episode  2090 score 108.5 episode length  201 average score 85.1 best score:109.3
# episode  2091 score 85.0 episode length  201 average score 85.0 best score:109.3
# episode  2092 score 93.9 episode length  201 average score 85.0 best score:109.3
# episode  2093 score 76.3 episode length  201 average score 85.1 best score:109.3
# episode  2094 score 113.9 episode length  201 average score 85.3 best score:109.3
# episode  2095 score 119.7 episode length  201 average score 86.7 best score:109.3
# episode  2096 score 53.6 episode length  201 average score 86.1 best score:109.3
# episode  2097 score 125.3 episode length  201 average score 86.7 best score:109.3
# episode  2098 score 99.6 episode length  201 average score 86.8 best score:109.3
# episode  2099 score 100.1 episode length  201 average score 86.7 best score:109.3
# episode  2100 score 104.9 episode length  201 average score 88.0 best score:109.3
# episode  2101 score 76.9 episode length  201 average score 87.5 best score:109.3
# episode  2102 score 80.5 episode length  201 average score 87.0 best score:109.3
# episode  2103 score 106.1 episode length  201 average score 87.0 best score:109.3
# episode  2104 score 97.4 episode length  201 average score 87.5 best score:109.3
# episode  2105 score 77.5 episode length  201 average score 87.3 best score:109.3
# episode  2106 score 72.0 episode length  201 average score 86.9 best score:109.3
# episode  2107 score 80.5 episode length  201 average score 86.6 best score:109.3
# episode  2108 score 122.5 episode length  201 average score 86.9 best score:109.3
# episode  2109 score 75.1 episode length  201 average score 86.8 best score:109.3
# episode  2110 score 81.2 episode length  201 average score 86.8 best score:109.3
# episode  2111 score 83.3 episode length  201 average score 86.4 best score:109.3
# episode  2112 score 58.4 episode length  201 average score 87.1 best score:109.3
# episode  2113 score 105.4 episode length  201 average score 87.0 best score:109.3
# episode  2114 score 58.0 episode length  201 average score 86.2 best score:109.3
# episode  2115 score 103.4 episode length  201 average score 87.1 best score:109.3
# episode  2116 score 82.5 episode length  201 average score 86.8 best score:109.3
# episode  2117 score 81.9 episode length  201 average score 86.5 best score:109.3
# episode  2118 score 88.1 episode length  201 average score 86.5 best score:109.3
# episode  2119 score 76.0 episode length  201 average score 86.3 best score:109.3
# episode  2120 score 134.0 episode length  201 average score 86.5 best score:109.3
# episode  2121 score 51.4 episode length  201 average score 86.2 best score:109.3
# episode  2122 score 134.8 episode length  201 average score 88.7 best score:109.3
# episode  2123 score 110.4 episode length  201 average score 88.4 best score:109.3
# episode  2124 score 121.3 episode length  201 average score 88.6 best score:109.3
# episode  2125 score 113.4 episode length  201 average score 88.1 best score:109.3
# episode  2126 score 75.0 episode length  201 average score 87.3 best score:109.3
# episode  2127 score 101.0 episode length  201 average score 87.5 best score:109.3
# episode  2128 score 95.6 episode length  201 average score 87.8 best score:109.3
# episode  2129 score 128.7 episode length  201 average score 88.0 best score:109.3
# episode  2130 score 116.5 episode length  201 average score 88.2 best score:109.3
# episode  2131 score 102.1 episode length  201 average score 88.2 best score:109.3
# episode  2132 score 93.1 episode length  201 average score 89.8 best score:109.3
# episode  2133 score 77.8 episode length  201 average score 89.4 best score:109.3
# episode  2134 score 109.7 episode length  201 average score 91.9 best score:109.3
# episode  2135 score 67.3 episode length  201 average score 91.4 best score:109.3
# episode  2136 score 111.2 episode length  201 average score 91.4 best score:109.3
# episode  2137 score 137.2 episode length  201 average score 92.4 best score:109.3
# episode  2138 score 114.1 episode length  201 average score 92.2 best score:109.3
# episode  2139 score 133.1 episode length  201 average score 93.8 best score:109.3
# episode  2140 score 96.4 episode length  201 average score 93.6 best score:109.3
# episode  2141 score 131.6 episode length  201 average score 94.0 best score:109.3
# episode  2142 score 108.2 episode length  201 average score 94.1 best score:109.3
# episode  2143 score 77.1 episode length  201 average score 94.0 best score:109.3
# episode  2144 score 111.0 episode length  201 average score 95.0 best score:109.3
# episode  2145 score 86.8 episode length  201 average score 95.0 best score:109.3
# episode  2146 score 118.4 episode length  201 average score 95.1 best score:109.3
# episode  2147 score 110.1 episode length  201 average score 95.0 best score:109.3
# episode  2148 score 38.7 episode length  201 average score 94.5 best score:109.3
# episode  2149 score 68.4 episode length  201 average score 94.3 best score:109.3
# episode  2150 score 90.2 episode length  201 average score 94.2 best score:109.3
# episode  2151 score 107.6 episode length  201 average score 94.4 best score:109.3
# episode  2152 score 52.0 episode length  201 average score 93.9 best score:109.3
# episode  2153 score 76.1 episode length  201 average score 93.7 best score:109.3
# episode  2154 score 62.8 episode length  201 average score 93.3 best score:109.3
# episode  2155 score 107.8 episode length  201 average score 93.2 best score:109.3
# episode  2156 score 50.6 episode length  201 average score 92.9 best score:109.3
# episode  2157 score 114.6 episode length  201 average score 93.2 best score:109.3
# episode  2158 score 131.1 episode length  201 average score 94.9 best score:109.3
# episode  2159 score 91.3 episode length  201 average score 94.9 best score:109.3
# episode  2160 score 63.9 episode length  201 average score 94.2 best score:109.3
# episode  2161 score 103.7 episode length  201 average score 94.1 best score:109.3
# episode  2162 score 97.7 episode length  201 average score 93.9 best score:109.3
# episode  2163 score 87.5 episode length  201 average score 93.6 best score:109.3
# episode  2164 score 70.0 episode length  201 average score 93.2 best score:109.3
# episode  2165 score 115.8 episode length  201 average score 94.0 best score:109.3
# episode  2166 score 71.9 episode length  201 average score 93.8 best score:109.3
# episode  2167 score 126.8 episode length  201 average score 94.1 best score:109.3
# episode  2168 score 68.0 episode length  201 average score 94.1 best score:109.3
# episode  2169 score 104.9 episode length  201 average score 94.7 best score:109.3
# episode  2170 score 66.5 episode length  201 average score 94.3 best score:109.3
# episode  2171 score 75.3 episode length  201 average score 93.9 best score:109.3
# episode  2172 score 128.4 episode length  201 average score 94.2 best score:109.3
# episode  2173 score 63.2 episode length  201 average score 93.8 best score:109.3
# episode  2174 score 134.3 episode length  201 average score 94.2 best score:109.3
# episode  2175 score 68.0 episode length  201 average score 93.7 best score:109.3
# episode  2176 score 112.8 episode length  201 average score 93.9 best score:109.3
# episode  2177 score 61.6 episode length  201 average score 94.0 best score:109.3
# episode  2178 score 123.2 episode length  201 average score 94.1 best score:109.3
# episode  2179 score 66.0 episode length  201 average score 93.9 best score:109.3
# episode  2180 score 89.2 episode length  201 average score 93.9 best score:109.3
# episode  2181 score 100.6 episode length  201 average score 94.4 best score:109.3
# episode  2182 score 132.1 episode length  201 average score 94.9 best score:109.3
# episode  2183 score 94.0 episode length  201 average score 94.7 best score:109.3
# episode  2184 score 111.9 episode length  201 average score 94.6 best score:109.3
# episode  2185 score 132.5 episode length  201 average score 95.1 best score:109.3
# episode  2186 score 56.3 episode length  201 average score 94.8 best score:109.3
# episode  2187 score 77.9 episode length  201 average score 94.6 best score:109.3
# episode  2188 score 127.9 episode length  201 average score 94.7 best score:109.3
# episode  2189 score 128.0 episode length  201 average score 95.1 best score:109.3
# episode  2190 score 101.2 episode length  201 average score 95.0 best score:109.3
# episode  2191 score 111.7 episode length  201 average score 95.3 best score:109.3
# episode  2192 score 118.6 episode length  201 average score 95.5 best score:109.3
# episode  2193 score 128.3 episode length  201 average score 96.0 best score:109.3
# episode  2194 score 113.7 episode length  201 average score 96.0 best score:109.3
# episode  2195 score 118.1 episode length  201 average score 96.0 best score:109.3
# episode  2196 score 80.0 episode length  201 average score 96.3 best score:109.3
# episode  2197 score 135.7 episode length  201 average score 96.4 best score:109.3
# episode  2198 score 75.8 episode length  201 average score 96.1 best score:109.3
# episode  2199 score 99.4 episode length  201 average score 96.1 best score:109.3
# episode  2200 score 107.1 episode length  201 average score 96.1 best score:109.3
# episode  2201 score 120.7 episode length  201 average score 96.6 best score:109.3
# episode  2202 score 49.1 episode length  80 average score 96.3 best score:109.3
# episode  2203 score 108.7 episode length  201 average score 96.3 best score:109.3
# episode  2204 score 96.7 episode length  201 average score 96.3 best score:109.3
# episode  2205 score 123.7 episode length  201 average score 96.8 best score:109.3
# episode  2206 score 110.6 episode length  201 average score 97.1 best score:109.3
# episode  2207 score 101.1 episode length  201 average score 97.3 best score:109.3
# episode  2208 score 112.7 episode length  201 average score 97.2 best score:109.3
# episode  2209 score 98.6 episode length  201 average score 97.5 best score:109.3
# episode  2210 score 114.5 episode length  201 average score 97.8 best score:109.3
# episode  2211 score 100.1 episode length  201 average score 98.0 best score:109.3
# episode  2212 score 54.7 episode length  201 average score 97.9 best score:109.3
# episode  2213 score 79.1 episode length  201 average score 97.7 best score:109.3
# episode  2214 score 77.7 episode length  201 average score 97.9 best score:109.3
# episode  2215 score 110.5 episode length  201 average score 98.0 best score:109.3
# episode  2216 score 67.5 episode length  201 average score 97.8 best score:109.3
# episode  2217 score 65.4 episode length  201 average score 97.6 best score:109.3
# episode  2218 score 128.6 episode length  201 average score 98.0 best score:109.3
# episode  2219 score 119.1 episode length  201 average score 98.5 best score:109.3
# episode  2220 score 70.2 episode length  201 average score 97.8 best score:109.3
# episode  2221 score 86.6 episode length  201 average score 98.2 best score:109.3
# episode  2222 score 79.1 episode length  201 average score 97.6 best score:109.3
# episode  2223 score 88.9 episode length  201 average score 97.4 best score:109.3
# episode  2224 score 74.1 episode length  201 average score 96.9 best score:109.3
# episode  2225 score 133.4 episode length  201 average score 97.1 best score:109.3
# episode  2226 score 97.2 episode length  201 average score 97.4 best score:109.3
# episode  2227 score 89.7 episode length  201 average score 97.3 best score:109.3
# episode  2228 score 82.6 episode length  201 average score 97.1 best score:109.3
# episode  2229 score 74.1 episode length  201 average score 96.6 best score:109.3
# episode  2230 score 95.0 episode length  201 average score 96.4 best score:109.3
# episode  2231 score 92.8 episode length  201 average score 96.3 best score:109.3
# episode  2232 score 122.2 episode length  201 average score 96.6 best score:109.3
# episode  2233 score 123.5 episode length  201 average score 97.0 best score:109.3
# episode  2234 score 114.9 episode length  201 average score 97.1 best score:109.3
# episode  2235 score 83.2 episode length  201 average score 97.2 best score:109.3
# episode  2236 score 116.8 episode length  201 average score 97.3 best score:109.3
# episode  2237 score 59.8 episode length  201 average score 96.5 best score:109.3
# episode  2238 score 109.2 episode length  201 average score 96.5 best score:109.3
# episode  2239 score 107.0 episode length  201 average score 96.2 best score:109.3
# episode  2240 score 120.3 episode length  201 average score 96.4 best score:109.3
# episode  2241 score 98.0 episode length  201 average score 96.1 best score:109.3
# episode  2242 score 115.5 episode length  201 average score 96.2 best score:109.3
# episode  2243 score 106.6 episode length  201 average score 96.5 best score:109.3
# episode  2244 score 97.3 episode length  201 average score 96.3 best score:109.3
# episode  2245 score 98.8 episode length  201 average score 96.5 best score:109.3
# episode  2246 score 114.2 episode length  201 average score 96.4 best score:109.3
# episode  2247 score 114.8 episode length  201 average score 96.5 best score:109.3
# episode  2248 score 110.5 episode length  201 average score 97.2 best score:109.3
# episode  2249 score 106.4 episode length  201 average score 97.6 best score:109.3
# episode  2250 score 89.3 episode length  201 average score 97.5 best score:109.3
# episode  2251 score 100.9 episode length  201 average score 97.5 best score:109.3
# episode  2252 score 94.5 episode length  201 average score 97.9 best score:109.3
# episode  2253 score 127.6 episode length  201 average score 98.4 best score:109.3
# episode  2254 score 127.1 episode length  201 average score 99.1 best score:109.3
# episode  2255 score 73.1 episode length  201 average score 98.7 best score:109.3
# episode  2256 score 75.4 episode length  201 average score 99.0 best score:109.3
# episode  2257 score 83.5 episode length  201 average score 98.7 best score:109.3
# episode  2258 score 116.5 episode length  201 average score 98.5 best score:109.3
# episode  2259 score 77.7 episode length  201 average score 98.4 best score:109.3
# episode  2260 score 118.4 episode length  201 average score 98.9 best score:109.3
# episode  2261 score 113.9 episode length  201 average score 99.0 best score:109.3
# episode  2262 score 122.6 episode length  201 average score 99.3 best score:109.3
# episode  2263 score 102.4 episode length  201 average score 99.4 best score:109.3
# episode  2264 score 74.7 episode length  201 average score 99.5 best score:109.3
# episode  2265 score 127.6 episode length  201 average score 99.6 best score:109.3
# episode  2266 score 124.3 episode length  201 average score 100.1 best score:109.3
# episode  2267 score 97.6 episode length  201 average score 99.8 best score:109.3
# episode  2268 score 109.3 episode length  201 average score 100.2 best score:109.3
# episode  2269 score 115.2 episode length  201 average score 100.3 best score:109.3
# episode  2270 score 116.0 episode length  201 average score 100.8 best score:109.3
# episode  2271 score 87.9 episode length  201 average score 101.0 best score:109.3
# episode  2272 score 56.9 episode length  201 average score 100.2 best score:109.3
# episode  2273 score 117.3 episode length  201 average score 100.8 best score:109.3
# episode  2274 score 52.4 episode length  201 average score 100.0 best score:109.3
# episode  2275 score 122.0 episode length  201 average score 100.5 best score:109.3
# episode  2276 score 106.3 episode length  201 average score 100.4 best score:109.3
# episode  2277 score 94.8 episode length  201 average score 100.8 best score:109.3
# episode  2278 score 88.6 episode length  201 average score 100.4 best score:109.3
# episode  2279 score 56.2 episode length  201 average score 100.3 best score:109.3
# episode  2280 score 127.9 episode length  201 average score 100.7 best score:109.3
# episode  2281 score 109.7 episode length  201 average score 100.8 best score:109.3
# episode  2282 score 80.9 episode length  201 average score 100.3 best score:109.3
# episode  2283 score 110.6 episode length  201 average score 100.5 best score:109.3
# episode  2284 score 119.4 episode length  201 average score 100.5 best score:109.3
# episode  2285 score 70.8 episode length  201 average score 99.9 best score:109.3
# episode  2286 score 121.7 episode length  201 average score 100.6 best score:109.3
# episode  2287 score 97.8 episode length  201 average score 100.8 best score:109.3
# episode  2288 score 129.5 episode length  201 average score 100.8 best score:109.3
# episode  2289 score 66.4 episode length  201 average score 100.2 best score:109.3
# episode  2290 score 103.6 episode length  201 average score 100.2 best score:109.3
# episode  2291 score 120.5 episode length  201 average score 100.3 best score:109.3
# episode  2292 score 66.2 episode length  201 average score 99.7 best score:109.3
# episode  2293 score 140.1 episode length  201 average score 99.9 best score:109.3
# episode  2294 score 104.3 episode length  201 average score 99.8 best score:109.3
# episode  2295 score 114.3 episode length  201 average score 99.7 best score:109.3
# episode  2296 score 81.3 episode length  201 average score 99.7 best score:109.3
# episode  2297 score 105.4 episode length  201 average score 99.4 best score:109.3
# episode  2298 score 119.8 episode length  201 average score 99.9 best score:109.3
# episode  2299 score 103.1 episode length  201 average score 99.9 best score:109.3
# episode  2300 score 63.2 episode length  201 average score 99.5 best score:109.3
# episode  2301 score 102.5 episode length  201 average score 99.3 best score:109.3
# episode  2302 score 78.6 episode length  201 average score 99.6 best score:109.3
# episode  2303 score 83.2 episode length  201 average score 99.3 best score:109.3
# episode  2304 score 119.8 episode length  201 average score 99.6 best score:109.3
# episode  2305 score 69.6 episode length  201 average score 99.0 best score:109.3
# episode  2306 score 64.9 episode length  201 average score 98.6 best score:109.3
# episode  2307 score 81.8 episode length  201 average score 98.4 best score:109.3
# episode  2308 score 77.8 episode length  201 average score 98.0 best score:109.3
# episode  2309 score 117.2 episode length  201 average score 98.2 best score:109.3
# episode  2310 score 107.8 episode length  201 average score 98.1 best score:109.3
# episode  2311 score 67.8 episode length  201 average score 97.8 best score:109.3
# episode  2312 score 97.0 episode length  201 average score 98.2 best score:109.3
# episode  2313 score 98.4 episode length  201 average score 98.4 best score:109.3
# episode  2314 score 101.3 episode length  201 average score 98.7 best score:109.3
# episode  2315 score 109.9 episode length  201 average score 98.7 best score:109.3
# episode  2316 score 128.7 episode length  201 average score 99.3 best score:109.3
# episode  2317 score 47.9 episode length  201 average score 99.1 best score:109.3
# episode  2318 score 107.0 episode length  201 average score 98.9 best score:109.3
# episode  2319 score 120.0 episode length  201 average score 98.9 best score:109.3
# episode  2320 score 67.6 episode length  201 average score 98.9 best score:109.3
# episode  2321 score 70.4 episode length  201 average score 98.7 best score:109.3
# episode  2322 score 157.2 episode length  201 average score 99.5 best score:109.3
# episode  2323 score 70.3 episode length  201 average score 99.3 best score:109.3
# episode  2324 score 62.5 episode length  201 average score 99.2 best score:109.3
# episode  2325 score 101.0 episode length  201 average score 98.9 best score:109.3
# episode  2326 score 94.7 episode length  201 average score 98.8 best score:109.3
# episode  2327 score 113.7 episode length  201 average score 99.1 best score:109.3
# episode  2328 score 115.0 episode length  201 average score 99.4 best score:109.3
# episode  2329 score 112.3 episode length  201 average score 99.8 best score:109.3
# episode  2330 score 112.3 episode length  201 average score 100.0 best score:109.3
# episode  2331 score 83.9 episode length  201 average score 99.9 best score:109.3
# episode  2332 score 70.0 episode length  201 average score 99.4 best score:109.3
# episode  2333 score 119.1 episode length  201 average score 99.3 best score:109.3
# episode  2334 score 136.0 episode length  201 average score 99.5 best score:109.3
# episode  2335 score 119.8 episode length  201 average score 99.9 best score:109.3
# episode  2336 score 111.9 episode length  201 average score 99.8 best score:109.3
# episode  2337 score 125.1 episode length  201 average score 100.5 best score:109.3
# episode  2338 score 104.2 episode length  201 average score 100.4 best score:109.3
# episode  2339 score 88.1 episode length  201 average score 100.3 best score:109.3
# episode  2340 score 121.2 episode length  201 average score 100.3 best score:109.3
# episode  2341 score 93.1 episode length  201 average score 100.2 best score:109.3
# episode  2342 score 118.5 episode length  201 average score 100.2 best score:109.3
# episode  2343 score 102.3 episode length  201 average score 100.2 best score:109.3
# episode  2344 score 105.1 episode length  201 average score 100.3 best score:109.3
# episode  2345 score 122.2 episode length  201 average score 100.5 best score:109.3
# episode  2346 score 105.0 episode length  201 average score 100.4 best score:109.3
# episode  2347 score 124.0 episode length  201 average score 100.5 best score:109.3
# episode  2348 score 128.4 episode length  201 average score 100.7 best score:109.3
# episode  2349 score 107.3 episode length  201 average score 100.7 best score:109.3
# episode  2350 score 101.2 episode length  201 average score 100.8 best score:109.3
# episode  2351 score 86.6 episode length  201 average score 100.7 best score:109.3
# episode  2352 score 114.2 episode length  201 average score 100.9 best score:109.3
# episode  2353 score 123.8 episode length  201 average score 100.8 best score:109.3
# episode  2354 score -1.8 episode length  201 average score 99.5 best score:109.3
# episode  2355 score 112.4 episode length  201 average score 99.9 best score:109.3
# episode  2356 score 98.3 episode length  201 average score 100.2 best score:109.3
# episode  2357 score 85.9 episode length  201 average score 100.2 best score:109.3
# episode  2358 score 103.0 episode length  201 average score 100.1 best score:109.3
# episode  2359 score 103.6 episode length  201 average score 100.3 best score:109.3
# episode  2360 score 109.2 episode length  201 average score 100.2 best score:109.3
# episode  2361 score 72.7 episode length  201 average score 99.8 best score:109.3
# episode  2362 score 95.2 episode length  201 average score 99.5 best score:109.3
# episode  2363 score 74.6 episode length  201 average score 99.3 best score:109.3
# episode  2364 score 105.7 episode length  201 average score 99.6 best score:109.3
# episode  2365 score 117.5 episode length  201 average score 99.5 best score:109.3
# episode  2366 score 90.4 episode length  201 average score 99.1 best score:109.3
# episode  2367 score 92.3 episode length  201 average score 99.1 best score:109.3
# episode  2368 score 63.2 episode length  201 average score 98.6 best score:109.3
# episode  2369 score 99.9 episode length  201 average score 98.5 best score:109.3
# episode  2370 score 54.4 episode length  201 average score 97.8 best score:109.3
# episode  2371 score 76.4 episode length  201 average score 97.7 best score:109.3
# episode  2372 score 88.5 episode length  201 average score 98.0 best score:109.3
# episode  2373 score 109.1 episode length  201 average score 98.0 best score:109.3
# episode  2374 score 112.0 episode length  201 average score 98.6 best score:109.3
# episode  2375 score 102.8 episode length  201 average score 98.4 best score:109.3
# episode  2376 score 91.1 episode length  201 average score 98.2 best score:109.3
# episode  2377 score 85.7 episode length  201 average score 98.1 best score:109.3
# episode  2378 score 122.8 episode length  201 average score 98.5 best score:109.3
# episode  2379 score 120.0 episode length  201 average score 99.1 best score:109.3
# episode  2380 score 127.3 episode length  201 average score 99.1 best score:109.3
# episode  2381 score 98.1 episode length  201 average score 99.0 best score:109.3
# episode  2382 score 88.0 episode length  201 average score 99.0 best score:109.3
# episode  2383 score 91.7 episode length  201 average score 98.9 best score:109.3
# episode  2384 score 108.4 episode length  201 average score 98.7 best score:109.3
# episode  2385 score 115.6 episode length  201 average score 99.2 best score:109.3
# episode  2386 score 116.9 episode length  201 average score 99.1 best score:109.3
# episode  2387 score 106.6 episode length  201 average score 99.2 best score:109.3
# episode  2388 score 95.8 episode length  201 average score 98.9 best score:109.3
# episode  2389 score 134.1 episode length  201 average score 99.6 best score:109.3
# episode  2390 score 108.9 episode length  201 average score 99.6 best score:109.3
# episode  2391 score 125.4 episode length  201 average score 99.7 best score:109.3
# episode  2392 score 56.4 episode length  201 average score 99.6 best score:109.3
# episode  2393 score 109.5 episode length  201 average score 99.3 best score:109.3
# episode  2394 score 101.1 episode length  201 average score 99.2 best score:109.3
# episode  2395 score 121.5 episode length  201 average score 99.3 best score:109.3
# episode  2396 score 64.1 episode length  201 average score 99.1 best score:109.3
# episode  2397 score 70.1 episode length  201 average score 98.8 best score:109.3
# episode  2398 score 83.7 episode length  201 average score 98.4 best score:109.3
# episode  2399 score 116.7 episode length  201 average score 98.6 best score:109.3
# episode  2400 score 90.7 episode length  201 average score 98.8 best score:109.3
# episode  2401 score 103.5 episode length  201 average score 98.9 best score:109.3
# episode  2402 score 98.3 episode length  201 average score 99.0 best score:109.3
# episode  2403 score 109.5 episode length  201 average score 99.3 best score:109.3
# episode  2404 score 67.9 episode length  201 average score 98.8 best score:109.3
# episode  2405 score 68.3 episode length  201 average score 98.8 best score:109.3
# episode  2406 score 68.5 episode length  201 average score 98.8 best score:109.3
# episode  2407 score 108.0 episode length  201 average score 99.1 best score:109.3
# episode  2408 score 111.2 episode length  201 average score 99.4 best score:109.3
# episode  2409 score 81.5 episode length  201 average score 99.1 best score:109.3
# episode  2410 score 95.8 episode length  201 average score 98.9 best score:109.3
# episode  2411 score 114.1 episode length  201 average score 99.4 best score:109.3
# episode  2412 score 81.8 episode length  201 average score 99.2 best score:109.3
# episode  2413 score 86.2 episode length  201 average score 99.1 best score:109.3
# episode  2414 score 85.4 episode length  201 average score 99.0 best score:109.3
# episode  2415 score 108.2 episode length  201 average score 98.9 best score:109.3
# episode  2416 score 112.9 episode length  201 average score 98.8 best score:109.3
# episode  2417 score 112.3 episode length  201 average score 99.4 best score:109.3
# episode  2418 score 109.1 episode length  201 average score 99.5 best score:109.3
# episode  2419 score 78.5 episode length  201 average score 99.0 best score:109.3
# episode  2420 score 97.9 episode length  201 average score 99.3 best score:109.3
# episode  2421 score 113.0 episode length  201 average score 99.8 best score:109.3
# episode  2422 score 83.4 episode length  201 average score 99.0 best score:109.3
# episode  2423 score 112.1 episode length  201 average score 99.5 best score:109.3
# episode  2424 score 140.5 episode length  201 average score 100.2 best score:109.3
# episode  2425 score 102.7 episode length  201 average score 100.2 best score:109.3
# episode  2426 score 94.3 episode length  201 average score 100.2 best score:109.3
# episode  2427 score 113.9 episode length  201 average score 100.2 best score:109.3
# episode  2428 score 130.1 episode length  201 average score 100.4 best score:109.3
# episode  2429 score 118.2 episode length  201 average score 100.5 best score:109.3
# episode  2430 score 112.7 episode length  201 average score 100.5 best score:109.3
# episode  2431 score 117.9 episode length  201 average score 100.8 best score:109.3
# episode  2432 score 112.7 episode length  201 average score 101.2 best score:109.3
# episode  2433 score 28.7 episode length  108 average score 100.3 best score:109.3
# episode  2434 score 104.3 episode length  201 average score 100.0 best score:109.3
# episode  2435 score 117.5 episode length  201 average score 100.0 best score:109.3
# episode  2436 score 121.1 episode length  201 average score 100.1 best score:109.3
# episode  2437 score 122.9 episode length  201 average score 100.1 best score:109.3
# episode  2438 score 116.7 episode length  201 average score 100.2 best score:109.3
# episode  2439 score 126.5 episode length  201 average score 100.6 best score:109.3
# episode  2440 score 100.5 episode length  201 average score 100.4 best score:109.3
# episode  2441 score 99.1 episode length  201 average score 100.4 best score:109.3
# episode  2442 score 70.9 episode length  201 average score 99.9 best score:109.3
# episode  2443 score 92.3 episode length  201 average score 99.8 best score:109.3
# episode  2444 score 83.9 episode length  201 average score 99.6 best score:109.3
# episode  2445 score 109.2 episode length  201 average score 99.5 best score:109.3
# episode  2446 score 104.7 episode length  201 average score 99.5 best score:109.3
# episode  2447 score 104.1 episode length  201 average score 99.3 best score:109.3
# ...
# episode  6687 score 194.6 episode length  201 average score 231.6 best score:235.5
# episode  6688 score 281.8 episode length  159 average score 233.1 best score:235.5
# episode  6689 score 112.0 episode length  201 average score 232.8 best score:235.5
# episode  6690 score 253.2 episode length  169 average score 232.6 best score:235.5
# episode  6691 score 170.2 episode length  201 average score 231.5 best score:235.5
# episode  6692 score 168.0 episode length  201 average score 230.2 best score:235.5
# episode  6693 score 177.3 episode length  201 average score 230.3 best score:235.5
# episode  6694 score 294.9 episode length  186 average score 230.3 best score:235.5
# episode  6695 score 296.9 episode length  181 average score 230.5 best score:235.5
# episode  6696 score 160.3 episode length  201 average score 229.1 best score:235.5
# episode  6697 score 140.7 episode length  201 average score 229.3 best score:235.5
# episode  6698 score 274.4 episode length  194 average score 229.5 best score:235.5
# episode  6699 score 180.2 episode length  201 average score 229.3 best score:235.5
# episode  6700 score 252.2 episode length  155 average score 229.3 best score:235.5
# episode  6701 score 287.7 episode length  187 average score 229.3 best score:235.5
# episode  6702 score 164.4 episode length  201 average score 229.2 best score:235.5
# episode  6703 score 255.9 episode length  180 average score 230.0 best score:235.5
# episode  6704 score 187.8 episode length  201 average score 230.2 best score:235.5
# episode  6705 score 153.7 episode length  201 average score 230.2 best score:235.5
# episode  6706 score 281.8 episode length  165 average score 231.3 best score:235.5
# episode  6707 score 160.7 episode length  201 average score 230.2 best score:235.5
# episode  6708 score 249.4 episode length  190 average score 230.8 best score:235.5
# episode  6709 score 171.5 episode length  201 average score 229.7 best score:235.5
# episode  6710 score 116.2 episode length  201 average score 228.1 best score:235.5
# episode  6711 score 293.2 episode length  180 average score 228.2 best score:235.5
# episode  6712 score 299.7 episode length  191 average score 228.5 best score:235.5
# episode  6713 score 171.1 episode length  201 average score 228.5 best score:235.5
# episode  6714 score 162.2 episode length  201 average score 227.7 best score:235.5
# episode  6715 score 255.7 episode length  175 average score 228.7 best score:235.5
# episode  6716 score 273.1 episode length  201 average score 229.7 best score:235.5
# episode  6717 score 194.2 episode length  201 average score 229.0 best score:235.5
# episode  6718 score 281.5 episode length  200 average score 229.0 best score:235.5
# episode  6719 score 181.1 episode length  201 average score 228.2 best score:235.5
# episode  6720 score 296.5 episode length  200 average score 228.3 best score:235.5
# episode  6721 score 282.7 episode length  166 average score 229.5 best score:235.5
# episode  6722 score 147.4 episode length  201 average score 228.2 best score:235.5
# episode  6723 score 170.2 episode length  201 average score 226.9 best score:235.5
# episode  6724 score 176.6 episode length  201 average score 226.8 best score:235.5
# episode  6725 score 293.6 episode length  193 average score 228.0 best score:235.5
# episode  6726 score 197.3 episode length  201 average score 227.3 best score:235.5
# episode  6727 score 267.0 episode length  161 average score 227.3 best score:235.5
# episode  6728 score 247.8 episode length  169 average score 228.1 best score:235.5
# episode  6729 score 264.4 episode length  188 average score 228.9 best score:235.5
# episode  6730 score 282.2 episode length  152 average score 229.3 best score:235.5
# episode  6731 score 280.5 episode length  185 average score 229.6 best score:235.5
# episode  6732 score 271.4 episode length  182 average score 229.7 best score:235.5
# episode  6733 score 124.8 episode length  201 average score 228.3 best score:235.5
# episode  6734 score 273.1 episode length  194 average score 229.2 best score:235.5
# episode  6735 score 269.6 episode length  165 average score 229.0 best score:235.5
# episode  6736 score 163.7 episode length  201 average score 227.8 best score:235.5
# episode  6737 score 184.3 episode length  201 average score 227.6 best score:235.5
# episode  6738 score 287.0 episode length  159 average score 227.4 best score:235.5
# episode  6739 score 186.1 episode length  201 average score 227.5 best score:235.5
# episode  6740 score 204.5 episode length  201 average score 226.7 best score:235.5
# episode  6741 score 268.9 episode length  185 average score 226.8 best score:235.5
# episode  6742 score 257.8 episode length  171 average score 226.7 best score:235.5
# episode  6743 score 270.8 episode length  171 average score 227.8 best score:235.5
# episode  6744 score 277.7 episode length  188 average score 228.8 best score:235.5
# episode  6745 score 271.4 episode length  179 average score 228.7 best score:235.5
# episode  6746 score 275.2 episode length  161 average score 228.7 best score:235.5
# episode  6747 score 229.8 episode length  199 average score 228.2 best score:235.5
# episode  6748 score 284.1 episode length  189 average score 229.7 best score:235.5
# episode  6749 score 311.2 episode length  163 average score 230.1 best score:235.5
# episode  6750 score 288.7 episode length  183 average score 230.3 best score:235.5
# episode  6751 score 293.5 episode length  188 average score 230.6 best score:235.5
# episode  6752 score 258.3 episode length  175 average score 230.6 best score:235.5
# episode  6753 score 263.7 episode length  158 average score 231.5 best score:235.5
# episode  6754 score 175.7 episode length  201 average score 230.6 best score:235.5
# episode  6755 score 288.0 episode length  161 average score 231.8 best score:235.5
# episode  6756 score 199.3 episode length  201 average score 232.2 best score:235.5
# episode  6757 score 291.7 episode length  161 average score 233.3 best score:235.5
# episode  6758 score 267.9 episode length  151 average score 233.2 best score:235.5
# episode  6759 score 260.7 episode length  166 average score 233.0 best score:235.5
# episode  6760 score 273.3 episode length  179 average score 233.8 best score:235.5
# episode  6761 score 246.7 episode length  185 average score 234.3 best score:235.5
# episode  6762 score 252.6 episode length  188 average score 235.0 best score:235.5
# episode  6763 score 263.6 episode length  165 average score 235.2 best score:235.5
# episode  6764 score 274.3 episode length  188 average score 235.3 best score:235.5
# episode  6765 score 182.3 episode length  201 average score 234.6 best score:235.5
# episode  6766 score 263.8 episode length  165 average score 235.9 best score:235.9
# episode  6767 score 261.9 episode length  184 average score 236.8 best score:236.8
# episode  6768 score 282.5 episode length  201 average score 237.1 best score:237.1
# episode  6769 score 252.3 episode length  175 average score 236.5 best score:237.1
# episode  6770 score 276.2 episode length  196 average score 236.2 best score:237.1
# episode  6771 score 275.0 episode length  197 average score 237.1 best score:237.1
# episode  6772 score 144.1 episode length  201 average score 235.9 best score:237.1
# episode  6773 score 174.8 episode length  201 average score 234.6 best score:237.1
# episode  6774 score 279.3 episode length  144 average score 234.8 best score:237.1
# episode  6775 score 261.9 episode length  182 average score 234.8 best score:237.1
# episode  6776 score 180.5 episode length  201 average score 233.9 best score:237.1
# episode  6777 score 266.2 episode length  164 average score 234.8 best score:237.1
# episode  6778 score 278.1 episode length  182 average score 235.8 best score:237.1
# episode  6779 score 171.3 episode length  201 average score 234.9 best score:237.1
# episode  6780 score 262.0 episode length  178 average score 234.6 best score:237.1
# episode  6781 score 280.5 episode length  178 average score 235.6 best score:237.1
# episode  6782 score 152.0 episode length  201 average score 234.3 best score:237.1
# episode  6783 score 192.7 episode length  201 average score 233.4 best score:237.1
# episode  6784 score 164.7 episode length  201 average score 233.3 best score:237.1
# episode  6785 score 196.6 episode length  201 average score 232.7 best score:237.1
# episode  6786 score 155.8 episode length  201 average score 232.7 best score:237.1
# episode  6787 score 279.2 episode length  164 average score 233.5 best score:237.1
# episode  6788 score 250.4 episode length  178 average score 233.2 best score:237.1
# episode  6789 score 272.1 episode length  196 average score 234.8 best score:237.1
# episode  6790 score 264.2 episode length  192 average score 234.9 best score:237.1
# episode  6791 score 164.7 episode length  201 average score 234.9 best score:237.1
# episode  6792 score 124.2 episode length  201 average score 234.4 best score:237.1
# episode  6793 score 255.1 episode length  188 average score 235.2 best score:237.1
# episode  6794 score 197.1 episode length  201 average score 234.2 best score:237.1
# episode  6795 score 272.0 episode length  158 average score 234.0 best score:237.1
# episode  6796 score 172.5 episode length  201 average score 234.1 best score:237.1
# episode  6797 score 166.1 episode length  201 average score 234.3 best score:237.1
# episode  6798 score 240.2 episode length  190 average score 234.0 best score:237.1
# episode  6799 score 176.3 episode length  201 average score 234.0 best score:237.1
# episode  6800 score 264.8 episode length  178 average score 234.1 best score:237.1
# episode  6801 score 285.5 episode length  198 average score 234.1 best score:237.1
# episode  6802 score 239.3 episode length  191 average score 234.8 best score:237.1
# episode  6803 score 186.0 episode length  201 average score 234.1 best score:237.1
# episode  6804 score 161.9 episode length  201 average score 233.9 best score:237.1
# episode  6805 score 260.3 episode length  176 average score 234.9 best score:237.1
# episode  6806 score 148.8 episode length  201 average score 233.6 best score:237.1
# episode  6807 score 247.9 episode length  161 average score 234.5 best score:237.1
# episode  6808 score 193.4 episode length  201 average score 233.9 best score:237.1
# episode  6809 score 174.6 episode length  201 average score 233.9 best score:237.1
# episode  6810 score 258.1 episode length  174 average score 235.4 best score:237.1
# episode  6811 score 200.0 episode length  201 average score 234.4 best score:237.1
# episode  6812 score 149.9 episode length  201 average score 232.9 best score:237.1
# episode  6813 score 275.6 episode length  193 average score 234.0 best score:237.1
# episode  6814 score 154.6 episode length  201 average score 233.9 best score:237.1
# episode  6815 score 258.5 episode length  159 average score 233.9 best score:237.1
# episode  6816 score 297.0 episode length  187 average score 234.2 best score:237.1
# episode  6817 score 283.8 episode length  201 average score 235.1 best score:237.1
# episode  6818 score 191.3 episode length  201 average score 234.2 best score:237.1
# episode  6819 score 258.1 episode length  164 average score 234.9 best score:237.1
# episode  6820 score 302.3 episode length  174 average score 235.0 best score:237.1
# episode  6821 score 252.1 episode length  182 average score 234.7 best score:237.1
# episode  6822 score 180.6 episode length  201 average score 235.0 best score:237.1
# episode  6823 score 295.2 episode length  147 average score 236.3 best score:237.1
# episode  6824 score 195.8 episode length  201 average score 236.5 best score:237.1
# episode  6825 score 298.6 episode length  189 average score 236.5 best score:237.1
# episode  6826 score 272.3 episode length  188 average score 237.3 best score:237.3
# episode  6827 score 249.8 episode length  170 average score 237.1 best score:237.3
# episode  6828 score 291.5 episode length  145 average score 237.5 best score:237.5
# episode  6829 score 278.2 episode length  197 average score 237.7 best score:237.7
# episode  6830 score 183.2 episode length  201 average score 236.7 best score:237.7
# episode  6831 score 270.6 episode length  182 average score 236.6 best score:237.7
# episode  6832 score 258.1 episode length  171 average score 236.4 best score:237.7
# episode  6833 score 201.9 episode length  201 average score 237.2 best score:237.7
# episode  6834 score 274.7 episode length  190 average score 237.2 best score:237.7
# episode  6835 score 185.0 episode length  201 average score 236.4 best score:237.7
# episode  6836 score 278.4 episode length  181 average score 237.5 best score:237.7
# episode  6837 score 289.0 episode length  189 average score 238.6 best score:238.6
# episode  6838 score 176.0 episode length  201 average score 237.5 best score:238.6
# episode  6839 score 267.6 episode length  154 average score 238.3 best score:238.6
# episode  6840 score 298.7 episode length  140 average score 239.2 best score:239.2
# episode  6841 score 164.5 episode length  201 average score 238.2 best score:239.2
# episode  6842 score 268.7 episode length  173 average score 238.3 best score:239.2
# episode  6843 score 274.3 episode length  187 average score 238.3 best score:239.2
# episode  6844 score 304.5 episode length  201 average score 238.6 best score:239.2
# episode  6845 score 278.8 episode length  195 average score 238.7 best score:239.2
# episode  6846 score 157.6 episode length  201 average score 237.5 best score:239.2
# episode  6847 score 289.6 episode length  148 average score 238.1 best score:239.2
# episode  6848 score 179.2 episode length  201 average score 237.0 best score:239.2
# episode  6849 score 270.5 episode length  150 average score 236.6 best score:239.2
# episode  6850 score 293.5 episode length  201 average score 236.7 best score:239.2
# episode  6851 score 300.3 episode length  198 average score 236.8 best score:239.2
# episode  6852 score 307.2 episode length  171 average score 237.2 best score:239.2
# episode  6853 score 181.8 episode length  201 average score 236.4 best score:239.2
# episode  6854 score 268.9 episode length  177 average score 237.4 best score:239.2
# episode  6855 score 208.4 episode length  201 average score 236.6 best score:239.2
# episode  6856 score 283.3 episode length  170 average score 237.4 best score:239.2
# episode  6857 score 300.7 episode length  178 average score 237.5 best score:239.2
# episode  6858 score 268.6 episode length  178 average score 237.5 best score:239.2
# episode  6859 score 172.8 episode length  201 average score 236.6 best score:239.2
# episode  6860 score 272.4 episode length  188 average score 236.6 best score:239.2
# episode  6861 score 283.2 episode length  161 average score 237.0 best score:239.2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-8974fedcd508> in <module>()
#      20         # print(observation_)
#      21         agent.remember(observation, action, reward, observation_, done)
# ---> 22         agent.learn()
#      23         score += reward
#      24         observation = observation_
#
# <ipython-input-8-838c61c618c3> in learn(self)
#      94         self.critic.optimizer.zero_grad()
#      95         critic_loss = F.mse_loss(target, critic_value)
# ---> 96         critic_loss.backward()
#      97         self.critic.optimizer.step()
#      98
#
# /usr/local/lib/python3.7/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     148
#     149
#
# KeyboardInterrupt:

# %%
agent.save_models()
# Out:
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip3 install box2d-py
# Out:
# Requirement already satisfied: box2d-py in /usr/local/lib/python3.7/dist-packages (2.3.8)

# %%
import glob
import io
import base64
from IPython.display import HTML

from IPython import display as ipythondisplay
from gym.wrappers import Monitor

from pyvirtualdisplay import Display

# ja jeg har tyv stjålet dette
# og nej jeg har ingen anse om hvad det gør men det virker!
def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %%
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
env = wrap_env(gym.make('LunarLanderContinuous-v2'))

# %%
observation = env.reset()

while True:
  
    env.render()
    
    #your agent goes here
    action = agent.choose_action(observation)
         
    observation, reward, done, info = env.step(action) 
   
        
    if done: 
      break;
            
env.close()
show_video()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-5d9d0535f49b> in <module>()
# ----> 1 observation = env.reset()
#       2
#       3 while True:
#       4
#       5     env.render()
#
# /usr/local/lib/python3.7/dist-packages/gym/wrappers/monitor.py in reset(self, **kwargs)
#      37         self._before_reset()
#      38         observation = self.env.reset(**kwargs)
# ---> 39         self._after_reset(observation)
#      40
#      41         return observation
#
# /usr/local/lib/python3.7/dist-packages/gym/wrappers/monitor.py in _after_reset(self, observation)
#     183         self.stats_recorder.after_reset(observation)
#     184
# --> 185         self.reset_video_recorder()
#     186
#     187         # Bump *after* all reset activity has finished
#
# /usr/local/lib/python3.7/dist-packages/gym/wrappers/monitor.py in reset_video_recorder(self)
#     204             enabled=self._video_enabled(),
#     205         )
# --> 206         self.video_recorder.capture_frame()
#     207
#     208     def _close_video_recorder(self):
#
# /usr/local/lib/python3.7/dist-packages/gym/wrappers/monitoring/video_recorder.py in capture_frame(self)
#      99
#     100         render_mode = 'ansi' if self.ansi_mode else 'rgb_array'
# --> 101         frame = self.env.render(mode=render_mode)
#     102
#     103         if frame is None:
#
# /usr/local/lib/python3.7/dist-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/box2d/lunar_lander.py in render(self, mode)
#     339
#     340     def render(self, mode='human'):
# --> 341         from gym.envs.classic_control import rendering
#     342         if self.viewer is None:
#     343             self.viewer = rendering.Viewer(VIEWPORT_W, VIEWPORT_H)
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/classic_control/rendering.py in <module>()
#      23
#      24 try:
# ---> 25     from pyglet.gl import *
#      26 except ImportError as e:
#      27     raise ImportError('''
#
# /usr/local/lib/python3.7/dist-packages/pyglet/gl/__init__.py in <module>()
#     233 elif compat_platform == 'darwin':
#     234     from .cocoa import CocoaConfig as Config
# --> 235 del base  # noqa: F821
#     236
#     237
#
# NameError: name 'base' is not defined

# %% [markdown]
# # Sweep

# %%
env = CartPoleEnv(use_theta_threshold=True)

n_sweeps = 20

n_games = 12000

n_steps=200

noise_sigma_list = []
fc1_list = []
fc2_list = []
alpha_list = []
beta_list = []

best_score_list = []

for j in range(n_sweeps):


  noise_sigma = np.random.choice([1, 0.5, 0.1, 0.05, 0.01])
  fc1 = np.random.choice([400, 300, 200, 100, 70, 50])
  fc2 = np.random.choice([400, 300, 200, 100, 70, 50])
  alpha = np.random.choice([0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001])
  beta = np.random.choice([0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001])

  # str(alpha) +'_'+ str(beta) +'_'+ str(gamma) +'_' +str(fc1_dims) +'_'+ str(fc2_dims) +'_'+ str(noise_sigma)
  alpha = 0.0001
  beta = 0.001
  gamma = 0.99
  fc1 = 300
  fc2 = 100
  noise_sigma = 0.2

  print(n_sweeps)
  print('noise_sigma: ',noise_sigma)
  print('fc1 ',fc1)
  print('fc2 ',fc2)
  print('alpha ', alpha)
  print('beta ',beta)



  noise_sigma_list.append(noise_sigma)
  fc1_list.append(fc1)
  fc2_list.append(fc2)
  alpha_list.append(alpha)
  beta_list.append(beta)

  agent = Agent(alpha=alpha, beta=beta, 
                  input_dims=env.observation_space.shape, output_bounds=15,
                  tau=0.001,
                  fc1_dims=fc1, fc2_dims=fc2, 
                  n_actions=1,
                  noise_sigma = noise_sigma)

  # agent.load_models()


  best_score = env.reward_range[0]
  score_history = []
  score_action_history = []

  for i in range(n_games):
      observation = env.reset()
      # print(observation.shape)
      # print(observation)
      done = False
      score = 0
      agent.noise.reset()
      k=0
      while not done:
          # env.render()
          k+=1
          
          action = agent.choose_action(observation)[0]
          # print(action)
          observation_, reward, done, info = env.step_force(action)
          # print(observation_.shape) 
          # print(observation_)
          agent.remember(observation, action, reward, observation_, done)
          agent.learn()
          score += reward
          observation = observation_
          if k>n_steps:
              done=True


      score_history.append(score)
      avg_score = np.mean(score_history[-100:])


      if avg_score > best_score and i > 80:
          best_score = avg_score
          agent.save_models()

      # print('episode ', i, 'score %.1f' % score,'episode length ',k,
      #         'average score %.1f' % avg_score)
      print('episode ', i, 'score %.1f' % score,'episode length ',k,
            'average score %.1f' % avg_score, 'best score:%.1f' %best_score)
  best_score_list.append(best_score)
# Out:
# Streaming output truncated to the last 5000 lines.
# episode  1236 score 26.7 episode length  27 average score 32.0 best score:47.7
# episode  1237 score 10.2 episode length  19 average score 31.9 best score:47.7
# episode  1238 score 25.6 episode length  20 average score 31.9 best score:47.7
# episode  1239 score 343.7 episode length  201 average score 34.3 best score:47.7
# episode  1240 score 4.9 episode length  14 average score 34.2 best score:47.7
# episode  1241 score 46.4 episode length  30 average score 34.6 best score:47.7
# episode  1242 score 83.9 episode length  67 average score 35.0 best score:47.7
# episode  1243 score 5.8 episode length  25 average score 34.8 best score:47.7
# episode  1244 score -4.5 episode length  16 average score 34.8 best score:47.7
# episode  1245 score 94.6 episode length  59 average score 34.5 best score:47.7
# episode  1246 score 22.5 episode length  25 average score 34.5 best score:47.7
# episode  1247 score -0.3 episode length  13 average score 33.6 best score:47.7
# episode  1248 score -30.9 episode length  11 average score 33.1 best score:47.7
# episode  1249 score 127.4 episode length  86 average score 34.4 best score:47.7
# episode  1250 score 29.3 episode length  30 average score 34.2 best score:47.7
# episode  1251 score 114.6 episode length  72 average score 35.3 best score:47.7
# episode  1252 score 43.5 episode length  40 average score 35.8 best score:47.7
# episode  1253 score 40.5 episode length  31 average score 36.0 best score:47.7
# episode  1254 score -18.3 episode length  9 average score 35.4 best score:47.7
# episode  1255 score 8.1 episode length  21 average score 35.8 best score:47.7
# episode  1256 score 0.2 episode length  10 average score 34.5 best score:47.7
# episode  1257 score 102.9 episode length  67 average score 35.1 best score:47.7
# episode  1258 score 288.2 episode length  189 average score 37.7 best score:47.7
# episode  1259 score 16.8 episode length  21 average score 36.1 best score:47.7
# episode  1260 score 39.1 episode length  31 average score 36.1 best score:47.7
# episode  1261 score 53.5 episode length  42 average score 36.3 best score:47.7
# episode  1262 score 27.1 episode length  28 average score 36.1 best score:47.7
# episode  1263 score 32.3 episode length  30 average score 36.1 best score:47.7
# episode  1264 score -7.9 episode length  14 average score 36.0 best score:47.7
# episode  1265 score -15.1 episode length  15 average score 35.8 best score:47.7
# episode  1266 score 30.1 episode length  27 average score 36.0 best score:47.7
# episode  1267 score 100.2 episode length  64 average score 36.9 best score:47.7
# episode  1268 score 24.5 episode length  20 average score 36.9 best score:47.7
# episode  1269 score 38.0 episode length  45 average score 36.8 best score:47.7
# episode  1270 score 31.5 episode length  32 average score 36.7 best score:47.7
# episode  1271 score 12.7 episode length  19 average score 36.8 best score:47.7
# episode  1272 score -6.0 episode length  13 average score 35.9 best score:47.7
# episode  1273 score 7.1 episode length  18 average score 35.9 best score:47.7
# episode  1274 score 61.3 episode length  40 average score 36.4 best score:47.7
# episode  1275 score 59.5 episode length  51 average score 36.9 best score:47.7
# episode  1276 score 72.6 episode length  44 average score 37.7 best score:47.7
# episode  1277 score 12.1 episode length  15 average score 38.0 best score:47.7
# episode  1278 score 39.3 episode length  37 average score 37.9 best score:47.7
# episode  1279 score 37.3 episode length  38 average score 38.0 best score:47.7
# episode  1280 score 45.5 episode length  32 average score 38.4 best score:47.7
# episode  1281 score 4.6 episode length  21 average score 37.8 best score:47.7
# episode  1282 score 38.7 episode length  31 average score 36.8 best score:47.7
# episode  1283 score 95.3 episode length  68 average score 37.9 best score:47.7
# episode  1284 score 116.4 episode length  74 average score 39.1 best score:47.7
# episode  1285 score 39.8 episode length  30 average score 39.7 best score:47.7
# episode  1286 score 1.6 episode length  14 average score 40.0 best score:47.7
# episode  1287 score -9.2 episode length  13 average score 40.0 best score:47.7
# episode  1288 score 44.7 episode length  34 average score 40.0 best score:47.7
# episode  1289 score 33.4 episode length  22 average score 39.6 best score:47.7
# episode  1290 score 36.0 episode length  43 average score 40.1 best score:47.7
# episode  1291 score 3.6 episode length  15 average score 39.8 best score:47.7
# episode  1292 score 63.8 episode length  46 average score 39.9 best score:47.7
# episode  1293 score 10.5 episode length  15 average score 40.0 best score:47.7
# episode  1294 score 15.4 episode length  33 average score 40.0 best score:47.7
# episode  1295 score 4.6 episode length  14 average score 39.9 best score:47.7
# episode  1296 score 17.6 episode length  16 average score 40.0 best score:47.7
# episode  1297 score 22.8 episode length  33 average score 38.5 best score:47.7
# episode  1298 score 32.4 episode length  34 average score 38.7 best score:47.7
# episode  1299 score 55.1 episode length  53 average score 39.2 best score:47.7
# episode  1300 score 88.9 episode length  67 average score 40.1 best score:47.7
# episode  1301 score 64.4 episode length  46 average score 40.2 best score:47.7
# episode  1302 score -4.1 episode length  20 average score 39.7 best score:47.7
# episode  1303 score 35.4 episode length  28 average score 40.1 best score:47.7
# episode  1304 score 50.9 episode length  39 average score 40.1 best score:47.7
# episode  1305 score 4.9 episode length  20 average score 39.4 best score:47.7
# episode  1306 score 44.4 episode length  56 average score 39.3 best score:47.7
# episode  1307 score 32.6 episode length  27 average score 39.6 best score:47.7
# episode  1308 score 16.8 episode length  32 average score 39.5 best score:47.7
# episode  1309 score -7.7 episode length  16 average score 39.2 best score:47.7
# episode  1310 score -0.6 episode length  14 average score 39.2 best score:47.7
# episode  1311 score 52.6 episode length  40 average score 38.7 best score:47.7
# episode  1312 score 18.8 episode length  20 average score 38.6 best score:47.7
# episode  1313 score 27.0 episode length  34 average score 37.5 best score:47.7
# episode  1314 score 69.4 episode length  47 average score 38.0 best score:47.7
# episode  1315 score 6.6 episode length  14 average score 37.6 best score:47.7
# episode  1316 score 50.4 episode length  32 average score 38.1 best score:47.7
# episode  1317 score 17.3 episode length  18 average score 38.0 best score:47.7
# episode  1318 score 18.1 episode length  19 average score 38.0 best score:47.7
# episode  1319 score 47.0 episode length  38 average score 38.4 best score:47.7
# episode  1320 score 10.0 episode length  23 average score 38.5 best score:47.7
# episode  1321 score 100.8 episode length  82 average score 39.4 best score:47.7
# episode  1322 score 121.1 episode length  86 average score 40.5 best score:47.7
# episode  1323 score 2.0 episode length  12 average score 40.3 best score:47.7
# episode  1324 score 118.6 episode length  82 average score 41.7 best score:47.7
# episode  1325 score 24.6 episode length  25 average score 41.7 best score:47.7
# episode  1326 score -3.3 episode length  19 average score 41.1 best score:47.7
# episode  1327 score 30.0 episode length  34 average score 41.0 best score:47.7
# episode  1328 score 67.9 episode length  43 average score 41.8 best score:47.7
# episode  1329 score -3.2 episode length  13 average score 41.2 best score:47.7
# episode  1330 score 43.4 episode length  30 average score 41.7 best score:47.7
# episode  1331 score 27.7 episode length  42 average score 41.5 best score:47.7
# episode  1332 score 34.3 episode length  30 average score 41.0 best score:47.7
# episode  1333 score -31.0 episode length  14 average score 40.3 best score:47.7
# episode  1334 score 65.0 episode length  88 average score 39.3 best score:47.7
# episode  1335 score -18.3 episode length  11 average score 39.3 best score:47.7
# episode  1336 score 26.6 episode length  28 average score 39.3 best score:47.7
# episode  1337 score 10.9 episode length  30 average score 39.3 best score:47.7
# episode  1338 score 70.6 episode length  45 average score 39.7 best score:47.7
# episode  1339 score -4.1 episode length  16 average score 36.2 best score:47.7
# episode  1340 score 20.9 episode length  24 average score 36.4 best score:47.7
# episode  1341 score 43.0 episode length  33 average score 36.4 best score:47.7
# episode  1342 score 52.7 episode length  42 average score 36.0 best score:47.7
# episode  1343 score 87.4 episode length  65 average score 36.9 best score:47.7
# episode  1344 score 57.1 episode length  40 average score 37.5 best score:47.7
# episode  1345 score 32.8 episode length  28 average score 36.9 best score:47.7
# episode  1346 score 12.2 episode length  29 average score 36.8 best score:47.7
# episode  1347 score 85.2 episode length  79 average score 37.6 best score:47.7
# episode  1348 score 34.5 episode length  54 average score 38.3 best score:47.7
# episode  1349 score 110.8 episode length  75 average score 38.1 best score:47.7
# episode  1350 score 41.6 episode length  31 average score 38.2 best score:47.7
# episode  1351 score -13.9 episode length  13 average score 36.9 best score:47.7
# episode  1352 score 55.6 episode length  43 average score 37.1 best score:47.7
# episode  1353 score 148.4 episode length  101 average score 38.1 best score:47.7
# episode  1354 score 176.9 episode length  136 average score 40.1 best score:47.7
# episode  1355 score -7.5 episode length  19 average score 39.9 best score:47.7
# episode  1356 score 10.1 episode length  34 average score 40.0 best score:47.7
# episode  1357 score 22.3 episode length  23 average score 39.2 best score:47.7
# episode  1358 score 34.2 episode length  29 average score 36.7 best score:47.7
# episode  1359 score 215.0 episode length  139 average score 38.7 best score:47.7
# episode  1360 score 114.4 episode length  73 average score 39.4 best score:47.7
# episode  1361 score 35.8 episode length  25 average score 39.2 best score:47.7
# episode  1362 score -3.5 episode length  14 average score 38.9 best score:47.7
# episode  1363 score 31.5 episode length  27 average score 38.9 best score:47.7
# episode  1364 score 27.7 episode length  34 average score 39.3 best score:47.7
# episode  1365 score 54.2 episode length  40 average score 40.0 best score:47.7
# episode  1366 score 41.2 episode length  35 average score 40.1 best score:47.7
# episode  1367 score 4.6 episode length  11 average score 39.1 best score:47.7
# episode  1368 score 20.0 episode length  22 average score 39.1 best score:47.7
# episode  1369 score -36.9 episode length  38 average score 38.3 best score:47.7
# episode  1370 score 13.2 episode length  13 average score 38.2 best score:47.7
# episode  1371 score 33.4 episode length  41 average score 38.4 best score:47.7
# episode  1372 score 56.5 episode length  54 average score 39.0 best score:47.7
# episode  1373 score 66.8 episode length  42 average score 39.6 best score:47.7
# episode  1374 score -26.1 episode length  14 average score 38.7 best score:47.7
# episode  1375 score 74.7 episode length  55 average score 38.9 best score:47.7
# episode  1376 score 10.9 episode length  24 average score 38.3 best score:47.7
# episode  1377 score 10.6 episode length  16 average score 38.2 best score:47.7
# episode  1378 score 4.4 episode length  46 average score 37.9 best score:47.7
# episode  1379 score 72.7 episode length  49 average score 38.2 best score:47.7
# episode  1380 score -8.5 episode length  17 average score 37.7 best score:47.7
# episode  1381 score 30.2 episode length  25 average score 38.0 best score:47.7
# episode  1382 score 20.4 episode length  19 average score 37.8 best score:47.7
# episode  1383 score -28.5 episode length  16 average score 36.5 best score:47.7
# episode  1384 score -32.6 episode length  8 average score 35.0 best score:47.7
# episode  1385 score 159.3 episode length  121 average score 36.2 best score:47.7
# episode  1386 score 5.2 episode length  16 average score 36.3 best score:47.7
# episode  1387 score 3.2 episode length  26 average score 36.4 best score:47.7
# episode  1388 score 12.1 episode length  26 average score 36.1 best score:47.7
# episode  1389 score 13.0 episode length  18 average score 35.9 best score:47.7
# episode  1390 score 107.7 episode length  71 average score 36.6 best score:47.7
# episode  1391 score 101.2 episode length  66 average score 37.6 best score:47.7
# episode  1392 score 15.3 episode length  14 average score 37.1 best score:47.7
# episode  1393 score 52.4 episode length  37 average score 37.5 best score:47.7
# episode  1394 score 18.1 episode length  20 average score 37.5 best score:47.7
# episode  1395 score 40.6 episode length  30 average score 37.9 best score:47.7
# episode  1396 score 14.6 episode length  25 average score 37.9 best score:47.7
# episode  1397 score -28.8 episode length  14 average score 37.3 best score:47.7
# episode  1398 score 8.3 episode length  17 average score 37.1 best score:47.7
# episode  1399 score 14.7 episode length  30 average score 36.7 best score:47.7
# episode  1400 score 17.7 episode length  27 average score 36.0 best score:47.7
# episode  1401 score 16.0 episode length  20 average score 35.5 best score:47.7
# episode  1402 score 86.2 episode length  60 average score 36.4 best score:47.7
# episode  1403 score 39.4 episode length  47 average score 36.4 best score:47.7
# episode  1404 score 8.9 episode length  17 average score 36.0 best score:47.7
# episode  1405 score 71.8 episode length  47 average score 36.7 best score:47.7
# episode  1406 score 53.5 episode length  43 average score 36.8 best score:47.7
# episode  1407 score 16.3 episode length  19 average score 36.6 best score:47.7
# episode  1408 score -1.5 episode length  16 average score 36.4 best score:47.7
# episode  1409 score 47.1 episode length  32 average score 37.0 best score:47.7
# episode  1410 score 155.0 episode length  104 average score 38.5 best score:47.7
# episode  1411 score 6.0 episode length  14 average score 38.1 best score:47.7
# episode  1412 score 32.8 episode length  32 average score 38.2 best score:47.7
# episode  1413 score 172.3 episode length  109 average score 39.7 best score:47.7
# episode  1414 score 43.9 episode length  39 average score 39.4 best score:47.7
# episode  1415 score 126.5 episode length  90 average score 40.6 best score:47.7
# episode  1416 score 50.8 episode length  40 average score 40.6 best score:47.7
# episode  1417 score 16.4 episode length  31 average score 40.6 best score:47.7
# episode  1418 score 99.0 episode length  65 average score 41.4 best score:47.7
# episode  1419 score 8.9 episode length  23 average score 41.0 best score:47.7
# episode  1420 score 24.3 episode length  20 average score 41.2 best score:47.7
# episode  1421 score 15.6 episode length  31 average score 40.3 best score:47.7
# episode  1422 score -5.3 episode length  48 average score 39.1 best score:47.7
# episode  1423 score 11.3 episode length  23 average score 39.2 best score:47.7
# episode  1424 score 82.5 episode length  52 average score 38.8 best score:47.7
# episode  1425 score 26.9 episode length  27 average score 38.8 best score:47.7
# episode  1426 score 13.5 episode length  37 average score 39.0 best score:47.7
# episode  1427 score -13.8 episode length  18 average score 38.5 best score:47.7
# episode  1428 score 31.8 episode length  31 average score 38.2 best score:47.7
# episode  1429 score 24.5 episode length  26 average score 38.5 best score:47.7
# episode  1430 score 46.3 episode length  47 average score 38.5 best score:47.7
# episode  1431 score 22.1 episode length  20 average score 38.4 best score:47.7
# episode  1432 score 31.8 episode length  23 average score 38.4 best score:47.7
# episode  1433 score 9.7 episode length  15 average score 38.8 best score:47.7
# episode  1434 score -20.6 episode length  12 average score 38.0 best score:47.7
# episode  1435 score 193.2 episode length  131 average score 40.1 best score:47.7
# episode  1436 score 17.8 episode length  21 average score 40.0 best score:47.7
# episode  1437 score 10.6 episode length  18 average score 40.0 best score:47.7
# episode  1438 score 31.3 episode length  25 average score 39.6 best score:47.7
# episode  1439 score 25.7 episode length  24 average score 39.9 best score:47.7
# episode  1440 score 34.8 episode length  44 average score 40.0 best score:47.7
# episode  1441 score 57.0 episode length  40 average score 40.2 best score:47.7
# episode  1442 score 105.2 episode length  66 average score 40.7 best score:47.7
# episode  1443 score 39.9 episode length  32 average score 40.2 best score:47.7
# episode  1444 score 28.8 episode length  26 average score 39.9 best score:47.7
# episode  1445 score 55.1 episode length  35 average score 40.2 best score:47.7
# episode  1446 score 153.3 episode length  100 average score 41.6 best score:47.7
# episode  1447 score -14.5 episode length  21 average score 40.6 best score:47.7
# episode  1448 score -9.1 episode length  17 average score 40.1 best score:47.7
# episode  1449 score 22.8 episode length  18 average score 39.3 best score:47.7
# episode  1450 score 38.4 episode length  31 average score 39.2 best score:47.7
# episode  1451 score -15.2 episode length  12 average score 39.2 best score:47.7
# episode  1452 score 69.3 episode length  53 average score 39.4 best score:47.7
# episode  1453 score 81.8 episode length  54 average score 38.7 best score:47.7
# episode  1454 score -4.8 episode length  18 average score 36.9 best score:47.7
# episode  1455 score 46.2 episode length  33 average score 37.4 best score:47.7
# episode  1456 score 8.1 episode length  19 average score 37.4 best score:47.7
# episode  1457 score 53.8 episode length  39 average score 37.7 best score:47.7
# episode  1458 score 3.6 episode length  32 average score 37.4 best score:47.7
# episode  1459 score -11.3 episode length  14 average score 35.1 best score:47.7
# episode  1460 score 31.8 episode length  24 average score 34.3 best score:47.7
# episode  1461 score 8.9 episode length  13 average score 34.0 best score:47.7
# episode  1462 score 9.5 episode length  13 average score 34.2 best score:47.7
# episode  1463 score 79.9 episode length  52 average score 34.7 best score:47.7
# episode  1464 score 21.8 episode length  29 average score 34.6 best score:47.7
# episode  1465 score 24.1 episode length  28 average score 34.3 best score:47.7
# episode  1466 score 9.6 episode length  16 average score 34.0 best score:47.7
# episode  1467 score 37.3 episode length  37 average score 34.3 best score:47.7
# episode  1468 score 66.2 episode length  54 average score 34.8 best score:47.7
# episode  1469 score 174.3 episode length  130 average score 36.9 best score:47.7
# episode  1470 score 96.6 episode length  65 average score 37.7 best score:47.7
# episode  1471 score 68.5 episode length  45 average score 38.1 best score:47.7
# episode  1472 score 41.6 episode length  43 average score 37.9 best score:47.7
# episode  1473 score 11.3 episode length  23 average score 37.4 best score:47.7
# episode  1474 score -5.6 episode length  14 average score 37.6 best score:47.7
# episode  1475 score 29.7 episode length  34 average score 37.1 best score:47.7
# episode  1476 score 19.2 episode length  28 average score 37.2 best score:47.7
# episode  1477 score 42.8 episode length  33 average score 37.5 best score:47.7
# episode  1478 score 5.2 episode length  15 average score 37.5 best score:47.7
# episode  1479 score 12.6 episode length  23 average score 36.9 best score:47.7
# episode  1480 score -13.5 episode length  14 average score 36.9 best score:47.7
# episode  1481 score 105.5 episode length  72 average score 37.6 best score:47.7
# episode  1482 score 20.4 episode length  24 average score 37.6 best score:47.7
# episode  1483 score 66.6 episode length  55 average score 38.6 best score:47.7
# episode  1484 score -3.5 episode length  14 average score 38.9 best score:47.7
# episode  1485 score 47.9 episode length  42 average score 37.8 best score:47.7
# episode  1486 score 46.3 episode length  38 average score 38.2 best score:47.7
# episode  1487 score 57.2 episode length  46 average score 38.7 best score:47.7
# episode  1488 score 10.2 episode length  31 average score 38.7 best score:47.7
# episode  1489 score 9.9 episode length  21 average score 38.7 best score:47.7
# episode  1490 score 14.8 episode length  33 average score 37.7 best score:47.7
# episode  1491 score 5.2 episode length  16 average score 36.8 best score:47.7
# episode  1492 score 53.3 episode length  36 average score 37.1 best score:47.7
# episode  1493 score 22.6 episode length  29 average score 36.8 best score:47.7
# episode  1494 score 27.9 episode length  20 average score 36.9 best score:47.7
# episode  1495 score 56.8 episode length  50 average score 37.1 best score:47.7
# episode  1496 score 35.6 episode length  29 average score 37.3 best score:47.7
# episode  1497 score 120.8 episode length  85 average score 38.8 best score:47.7
# episode  1498 score 85.2 episode length  52 average score 39.6 best score:47.7
# episode  1499 score 83.9 episode length  55 average score 40.3 best score:47.7
# episode  1500 score 77.7 episode length  51 average score 40.9 best score:47.7
# episode  1501 score 15.9 episode length  22 average score 40.9 best score:47.7
# episode  1502 score 27.2 episode length  28 average score 40.3 best score:47.7
# episode  1503 score 21.0 episode length  28 average score 40.1 best score:47.7
# episode  1504 score 70.0 episode length  51 average score 40.7 best score:47.7
# episode  1505 score 26.3 episode length  30 average score 40.3 best score:47.7
# episode  1506 score 9.8 episode length  22 average score 39.8 best score:47.7
# episode  1507 score -2.1 episode length  13 average score 39.6 best score:47.7
# episode  1508 score 3.4 episode length  14 average score 39.7 best score:47.7
# episode  1509 score 22.6 episode length  20 average score 39.4 best score:47.7
# episode  1510 score 30.4 episode length  25 average score 38.2 best score:47.7
# episode  1511 score 5.8 episode length  14 average score 38.2 best score:47.7
# episode  1512 score -4.8 episode length  13 average score 37.8 best score:47.7
# episode  1513 score -1.2 episode length  17 average score 36.1 best score:47.7
# episode  1514 score 33.9 episode length  31 average score 36.0 best score:47.7
# episode  1515 score 44.4 episode length  36 average score 35.2 best score:47.7
# episode  1516 score 125.1 episode length  75 average score 35.9 best score:47.7
# episode  1517 score 11.0 episode length  19 average score 35.9 best score:47.7
# episode  1518 score 58.1 episode length  45 average score 35.4 best score:47.7
# episode  1519 score 52.8 episode length  46 average score 35.9 best score:47.7
# episode  1520 score 12.3 episode length  23 average score 35.8 best score:47.7
# episode  1521 score 42.0 episode length  38 average score 36.0 best score:47.7
# episode  1522 score 206.2 episode length  129 average score 38.1 best score:47.7
# episode  1523 score 32.2 episode length  28 average score 38.4 best score:47.7
# episode  1524 score -2.3 episode length  14 average score 37.5 best score:47.7
# episode  1525 score 13.9 episode length  13 average score 37.4 best score:47.7
# episode  1526 score 91.3 episode length  71 average score 38.2 best score:47.7
# episode  1527 score 12.9 episode length  15 average score 38.4 best score:47.7
# episode  1528 score 114.3 episode length  77 average score 39.2 best score:47.7
# episode  1529 score 49.5 episode length  40 average score 39.5 best score:47.7
# episode  1530 score 35.7 episode length  32 average score 39.4 best score:47.7
# episode  1531 score 12.0 episode length  23 average score 39.3 best score:47.7
# episode  1532 score -7.3 episode length  11 average score 38.9 best score:47.7
# episode  1533 score 38.3 episode length  38 average score 39.2 best score:47.7
# episode  1534 score 0.5 episode length  17 average score 39.4 best score:47.7
# episode  1535 score 18.3 episode length  18 average score 37.6 best score:47.7
# episode  1536 score -12.6 episode length  10 average score 37.3 best score:47.7
# episode  1537 score 30.8 episode length  48 average score 37.5 best score:47.7
# episode  1538 score 5.7 episode length  15 average score 37.3 best score:47.7
# episode  1539 score 4.4 episode length  29 average score 37.1 best score:47.7
# episode  1540 score -2.3 episode length  11 average score 36.7 best score:47.7
# episode  1541 score 56.4 episode length  41 average score 36.7 best score:47.7
# episode  1542 score 35.7 episode length  45 average score 36.0 best score:47.7
# episode  1543 score 12.7 episode length  27 average score 35.7 best score:47.7
# episode  1544 score 1.5 episode length  16 average score 35.5 best score:47.7
# episode  1545 score -8.7 episode length  17 average score 34.8 best score:47.7
# episode  1546 score 45.7 episode length  40 average score 33.7 best score:47.7
# episode  1547 score 26.7 episode length  22 average score 34.2 best score:47.7
# episode  1548 score 4.0 episode length  17 average score 34.3 best score:47.7
# episode  1549 score 63.8 episode length  45 average score 34.7 best score:47.7
# episode  1550 score 32.6 episode length  33 average score 34.6 best score:47.7
# episode  1551 score 0.3 episode length  22 average score 34.8 best score:47.7
# episode  1552 score 82.1 episode length  60 average score 34.9 best score:47.7
# episode  1553 score 23.4 episode length  29 average score 34.3 best score:47.7
# episode  1554 score 38.6 episode length  34 average score 34.8 best score:47.7
# episode  1555 score 9.0 episode length  18 average score 34.4 best score:47.7
# episode  1556 score 29.5 episode length  26 average score 34.6 best score:47.7
# episode  1557 score 21.6 episode length  22 average score 34.3 best score:47.7
# episode  1558 score 52.5 episode length  41 average score 34.8 best score:47.7
# episode  1559 score 124.0 episode length  81 average score 36.1 best score:47.7
# episode  1560 score 34.7 episode length  33 average score 36.2 best score:47.7
# episode  1561 score 51.9 episode length  42 average score 36.6 best score:47.7
# episode  1562 score 7.5 episode length  17 average score 36.6 best score:47.7
# episode  1563 score 33.8 episode length  26 average score 36.1 best score:47.7
# episode  1564 score 46.7 episode length  34 average score 36.4 best score:47.7
# episode  1565 score 28.2 episode length  30 average score 36.4 best score:47.7
# episode  1566 score 69.9 episode length  50 average score 37.0 best score:47.7
# episode  1567 score 33.2 episode length  38 average score 37.0 best score:47.7
# episode  1568 score 2.9 episode length  20 average score 36.3 best score:47.7
# episode  1569 score -23.1 episode length  12 average score 34.4 best score:47.7
# episode  1570 score 39.6 episode length  36 average score 33.8 best score:47.7
# episode  1571 score -14.5 episode length  12 average score 33.0 best score:47.7
# episode  1572 score 24.6 episode length  27 average score 32.8 best score:47.7
# episode  1573 score 78.1 episode length  60 average score 33.5 best score:47.7
# episode  1574 score 115.4 episode length  71 average score 34.7 best score:47.7
# episode  1575 score 83.2 episode length  54 average score 35.2 best score:47.7
# episode  1576 score 26.4 episode length  37 average score 35.3 best score:47.7
# episode  1577 score -25.5 episode length  14 average score 34.6 best score:47.7
# episode  1578 score 75.5 episode length  53 average score 35.3 best score:47.7
# episode  1579 score -17.0 episode length  13 average score 35.0 best score:47.7
# episode  1580 score 32.8 episode length  35 average score 35.5 best score:47.7
# episode  1581 score 3.6 episode length  20 average score 34.4 best score:47.7
# episode  1582 score 27.6 episode length  27 average score 34.5 best score:47.7
# episode  1583 score 24.5 episode length  31 average score 34.1 best score:47.7
# episode  1584 score 74.1 episode length  50 average score 34.9 best score:47.7
# episode  1585 score -3.4 episode length  14 average score 34.4 best score:47.7
# episode  1586 score -4.5 episode length  12 average score 33.8 best score:47.7
# episode  1587 score 89.1 episode length  66 average score 34.2 best score:47.7
# episode  1588 score -3.2 episode length  15 average score 34.0 best score:47.7
# episode  1589 score -2.4 episode length  21 average score 33.9 best score:47.7
# episode  1590 score -4.3 episode length  22 average score 33.7 best score:47.7
# episode  1591 score 48.2 episode length  32 average score 34.1 best score:47.7
# episode  1592 score 98.5 episode length  78 average score 34.6 best score:47.7
# episode  1593 score 56.2 episode length  66 average score 34.9 best score:47.7
# episode  1594 score -7.0 episode length  15 average score 34.6 best score:47.7
# episode  1595 score -8.7 episode length  15 average score 33.9 best score:47.7
# episode  1596 score 25.7 episode length  26 average score 33.8 best score:47.7
# episode  1597 score -6.6 episode length  14 average score 32.6 best score:47.7
# episode  1598 score 44.4 episode length  35 average score 32.2 best score:47.7
# episode  1599 score 31.3 episode length  27 average score 31.6 best score:47.7
# episode  1600 score 73.2 episode length  63 average score 31.6 best score:47.7
# episode  1601 score 20.3 episode length  18 average score 31.6 best score:47.7
# episode  1602 score -7.6 episode length  17 average score 31.3 best score:47.7
# episode  1603 score 27.6 episode length  22 average score 31.3 best score:47.7
# episode  1604 score 9.0 episode length  16 average score 30.7 best score:47.7
# episode  1605 score 69.5 episode length  48 average score 31.2 best score:47.7
# episode  1606 score 45.0 episode length  28 average score 31.5 best score:47.7
# episode  1607 score 32.5 episode length  37 average score 31.9 best score:47.7
# episode  1608 score -2.4 episode length  17 average score 31.8 best score:47.7
# episode  1609 score 42.8 episode length  34 average score 32.0 best score:47.7
# episode  1610 score 130.0 episode length  88 average score 33.0 best score:47.7
# episode  1611 score -12.7 episode length  18 average score 32.8 best score:47.7
# episode  1612 score 78.5 episode length  54 average score 33.7 best score:47.7
# episode  1613 score 33.2 episode length  35 average score 34.0 best score:47.7
# episode  1614 score 5.7 episode length  26 average score 33.7 best score:47.7
# episode  1615 score 32.2 episode length  38 average score 33.6 best score:47.7
# episode  1616 score 103.9 episode length  75 average score 33.4 best score:47.7
# episode  1617 score 26.1 episode length  26 average score 33.5 best score:47.7
# episode  1618 score 17.5 episode length  15 average score 33.1 best score:47.7
# episode  1619 score 3.7 episode length  20 average score 32.6 best score:47.7
# episode  1620 score 19.6 episode length  19 average score 32.7 best score:47.7
# episode  1621 score 54.2 episode length  51 average score 32.8 best score:47.7
# episode  1622 score 58.9 episode length  41 average score 31.4 best score:47.7
# episode  1623 score 17.0 episode length  37 average score 31.2 best score:47.7
# episode  1624 score 0.7 episode length  16 average score 31.2 best score:47.7
# episode  1625 score 19.9 episode length  29 average score 31.3 best score:47.7
# episode  1626 score 138.4 episode length  93 average score 31.8 best score:47.7
# episode  1627 score 29.9 episode length  30 average score 31.9 best score:47.7
# episode  1628 score 9.6 episode length  22 average score 30.9 best score:47.7
# episode  1629 score 23.6 episode length  25 average score 30.6 best score:47.7
# episode  1630 score 48.2 episode length  53 average score 30.8 best score:47.7
# episode  1631 score 50.4 episode length  33 average score 31.1 best score:47.7
# episode  1632 score 5.9 episode length  21 average score 31.3 best score:47.7
# episode  1633 score 2.2 episode length  15 average score 30.9 best score:47.7
# episode  1634 score 10.1 episode length  17 average score 31.0 best score:47.7
# episode  1635 score 41.8 episode length  40 average score 31.2 best score:47.7
# episode  1636 score 8.2 episode length  13 average score 31.4 best score:47.7
# episode  1637 score 38.4 episode length  34 average score 31.5 best score:47.7
# episode  1638 score -8.3 episode length  14 average score 31.4 best score:47.7
# episode  1639 score -16.3 episode length  12 average score 31.2 best score:47.7
# episode  1640 score 139.7 episode length  98 average score 32.6 best score:47.7
# episode  1641 score 24.4 episode length  20 average score 32.3 best score:47.7
# episode  1642 score 16.1 episode length  15 average score 32.1 best score:47.7
# episode  1643 score 62.9 episode length  46 average score 32.6 best score:47.7
# episode  1644 score 43.2 episode length  35 average score 33.0 best score:47.7
# episode  1645 score 40.7 episode length  28 average score 33.5 best score:47.7
# episode  1646 score 0.1 episode length  14 average score 33.0 best score:47.7
# episode  1647 score 32.6 episode length  23 average score 33.1 best score:47.7
# episode  1648 score 27.1 episode length  35 average score 33.3 best score:47.7
# episode  1649 score 22.6 episode length  28 average score 32.9 best score:47.7
# episode  1650 score 59.9 episode length  56 average score 33.2 best score:47.7
# episode  1651 score 55.9 episode length  38 average score 33.7 best score:47.7
# episode  1652 score 42.3 episode length  30 average score 33.3 best score:47.7
# episode  1653 score 66.2 episode length  49 average score 33.8 best score:47.7
# episode  1654 score 26.6 episode length  25 average score 33.7 best score:47.7
# episode  1655 score 12.6 episode length  22 average score 33.7 best score:47.7
# episode  1656 score 21.0 episode length  29 average score 33.6 best score:47.7
# episode  1657 score 143.5 episode length  88 average score 34.8 best score:47.7
# episode  1658 score 78.3 episode length  53 average score 35.1 best score:47.7
# episode  1659 score 7.2 episode length  18 average score 33.9 best score:47.7
# episode  1660 score 7.8 episode length  21 average score 33.6 best score:47.7
# episode  1661 score 87.1 episode length  80 average score 34.0 best score:47.7
# episode  1662 score 13.8 episode length  16 average score 34.1 best score:47.7
# episode  1663 score 33.8 episode length  48 average score 34.1 best score:47.7
# episode  1664 score 28.7 episode length  24 average score 33.9 best score:47.7
# episode  1665 score 17.7 episode length  35 average score 33.8 best score:47.7
# episode  1666 score 46.3 episode length  47 average score 33.5 best score:47.7
# episode  1667 score 31.2 episode length  22 average score 33.5 best score:47.7
# episode  1668 score 11.2 episode length  24 average score 33.6 best score:47.7
# episode  1669 score 18.6 episode length  17 average score 34.0 best score:47.7
# episode  1670 score 54.2 episode length  46 average score 34.2 best score:47.7
# episode  1671 score 319.3 episode length  194 average score 37.5 best score:47.7
# episode  1672 score -2.0 episode length  12 average score 37.2 best score:47.7
# episode  1673 score 64.9 episode length  45 average score 37.1 best score:47.7
# episode  1674 score 5.9 episode length  16 average score 36.0 best score:47.7
# episode  1675 score 30.4 episode length  45 average score 35.5 best score:47.7
# episode  1676 score 22.7 episode length  20 average score 35.4 best score:47.7
# episode  1677 score -5.7 episode length  12 average score 35.6 best score:47.7
# episode  1678 score -25.0 episode length  12 average score 34.6 best score:47.7
# episode  1679 score 7.1 episode length  20 average score 34.9 best score:47.7
# episode  1680 score 74.5 episode length  65 average score 35.3 best score:47.7
# episode  1681 score 201.2 episode length  132 average score 37.3 best score:47.7
# episode  1682 score 10.6 episode length  26 average score 37.1 best score:47.7
# episode  1683 score -21.2 episode length  9 average score 36.6 best score:47.7
# episode  1684 score 79.4 episode length  66 average score 36.7 best score:47.7
# episode  1685 score 4.0 episode length  24 average score 36.8 best score:47.7
# episode  1686 score 17.6 episode length  22 average score 37.0 best score:47.7
# episode  1687 score -6.4 episode length  10 average score 36.0 best score:47.7
# episode  1688 score 57.1 episode length  44 average score 36.6 best score:47.7
# episode  1689 score 37.4 episode length  38 average score 37.0 best score:47.7
# episode  1690 score 4.7 episode length  16 average score 37.1 best score:47.7
# episode  1691 score 62.9 episode length  43 average score 37.3 best score:47.7
# episode  1692 score -4.3 episode length  11 average score 36.2 best score:47.7
# episode  1693 score 28.2 episode length  27 average score 36.0 best score:47.7
# episode  1694 score 38.9 episode length  38 average score 36.4 best score:47.7
# episode  1695 score 15.6 episode length  18 average score 36.7 best score:47.7
# episode  1696 score -2.7 episode length  15 average score 36.4 best score:47.7
# episode  1697 score 11.6 episode length  26 average score 36.6 best score:47.7
# episode  1698 score 14.2 episode length  18 average score 36.3 best score:47.7
# episode  1699 score 122.8 episode length  77 average score 37.2 best score:47.7
# episode  1700 score 15.1 episode length  16 average score 36.6 best score:47.7
# episode  1701 score -5.6 episode length  15 average score 36.3 best score:47.7
# episode  1702 score 1.8 episode length  19 average score 36.4 best score:47.7
# episode  1703 score -3.6 episode length  21 average score 36.1 best score:47.7
# episode  1704 score -8.5 episode length  14 average score 35.9 best score:47.7
# episode  1705 score 28.8 episode length  22 average score 35.5 best score:47.7
# episode  1706 score 32.9 episode length  32 average score 35.4 best score:47.7
# episode  1707 score 3.0 episode length  14 average score 35.1 best score:47.7
# episode  1708 score 24.2 episode length  19 average score 35.4 best score:47.7
# episode  1709 score 20.2 episode length  40 average score 35.2 best score:47.7
# episode  1710 score 40.7 episode length  46 average score 34.3 best score:47.7
# episode  1711 score 16.6 episode length  27 average score 34.6 best score:47.7
# episode  1712 score 42.1 episode length  33 average score 34.2 best score:47.7
# episode  1713 score 60.9 episode length  42 average score 34.5 best score:47.7
# episode  1714 score -12.2 episode length  12 average score 34.3 best score:47.7
# episode  1715 score 67.3 episode length  54 average score 34.6 best score:47.7
# episode  1716 score 6.6 episode length  35 average score 33.7 best score:47.7
# episode  1717 score 182.7 episode length  143 average score 35.2 best score:47.7
# episode  1718 score 17.2 episode length  29 average score 35.2 best score:47.7
# episode  1719 score 18.8 episode length  30 average score 35.4 best score:47.7
# episode  1720 score 13.3 episode length  18 average score 35.3 best score:47.7
# episode  1721 score 20.9 episode length  28 average score 35.0 best score:47.7
# episode  1722 score 137.6 episode length  100 average score 35.8 best score:47.7
# episode  1723 score 42.7 episode length  44 average score 36.0 best score:47.7
# episode  1724 score 16.8 episode length  20 average score 36.2 best score:47.7
# episode  1725 score 45.7 episode length  31 average score 36.5 best score:47.7
# episode  1726 score -2.4 episode length  13 average score 35.0 best score:47.7
# episode  1727 score 39.9 episode length  29 average score 35.1 best score:47.7
# episode  1728 score 72.1 episode length  58 average score 35.8 best score:47.7
# episode  1729 score -16.8 episode length  16 average score 35.4 best score:47.7
# episode  1730 score -36.4 episode length  15 average score 34.5 best score:47.7
# episode  1731 score -2.1 episode length  14 average score 34.0 best score:47.7
# episode  1732 score 177.7 episode length  123 average score 35.7 best score:47.7
# episode  1733 score 22.3 episode length  35 average score 35.9 best score:47.7
# episode  1734 score -8.4 episode length  11 average score 35.7 best score:47.7
# episode  1735 score 51.8 episode length  42 average score 35.8 best score:47.7
# episode  1736 score 65.5 episode length  40 average score 36.4 best score:47.7
# episode  1737 score -0.1 episode length  15 average score 36.0 best score:47.7
# episode  1738 score 19.6 episode length  22 average score 36.3 best score:47.7
# episode  1739 score 51.7 episode length  44 average score 37.0 best score:47.7
# episode  1740 score 25.0 episode length  22 average score 35.8 best score:47.7
# episode  1741 score 19.7 episode length  24 average score 35.8 best score:47.7
# episode  1742 score 27.0 episode length  32 average score 35.9 best score:47.7
# episode  1743 score -34.7 episode length  18 average score 34.9 best score:47.7
# episode  1744 score 5.4 episode length  13 average score 34.5 best score:47.7
# episode  1745 score 52.7 episode length  42 average score 34.7 best score:47.7
# episode  1746 score 56.5 episode length  47 average score 35.2 best score:47.7
# episode  1747 score -6.1 episode length  18 average score 34.8 best score:47.7
# episode  1748 score 2.4 episode length  14 average score 34.6 best score:47.7
# episode  1749 score 18.5 episode length  24 average score 34.5 best score:47.7
# episode  1750 score 102.5 episode length  79 average score 35.0 best score:47.7
# episode  1751 score 81.9 episode length  53 average score 35.2 best score:47.7
# episode  1752 score 24.1 episode length  22 average score 35.0 best score:47.7
# episode  1753 score 14.5 episode length  35 average score 34.5 best score:47.7
# episode  1754 score 54.8 episode length  45 average score 34.8 best score:47.7
# episode  1755 score -34.5 episode length  13 average score 34.3 best score:47.7
# episode  1756 score 18.2 episode length  26 average score 34.3 best score:47.7
# episode  1757 score 12.6 episode length  23 average score 33.0 best score:47.7
# episode  1758 score 123.2 episode length  92 average score 33.5 best score:47.7
# episode  1759 score 39.8 episode length  45 average score 33.8 best score:47.7
# episode  1760 score -2.3 episode length  16 average score 33.7 best score:47.7
# episode  1761 score 40.2 episode length  30 average score 33.2 best score:47.7
# episode  1762 score 19.4 episode length  18 average score 33.3 best score:47.7
# episode  1763 score 52.5 episode length  38 average score 33.5 best score:47.7
# episode  1764 score 23.1 episode length  22 average score 33.4 best score:47.7
# episode  1765 score 65.5 episode length  48 average score 33.9 best score:47.7
# episode  1766 score 17.5 episode length  50 average score 33.6 best score:47.7
# episode  1767 score 85.2 episode length  66 average score 34.1 best score:47.7
# episode  1768 score 121.0 episode length  85 average score 35.2 best score:47.7
# episode  1769 score 67.7 episode length  45 average score 35.7 best score:47.7
# episode  1770 score 25.3 episode length  50 average score 35.4 best score:47.7
# episode  1771 score 33.9 episode length  26 average score 32.6 best score:47.7
# episode  1772 score 6.0 episode length  16 average score 32.7 best score:47.7
# episode  1773 score 33.7 episode length  29 average score 32.3 best score:47.7
# episode  1774 score 76.8 episode length  53 average score 33.1 best score:47.7
# episode  1775 score 51.2 episode length  46 average score 33.3 best score:47.7
# episode  1776 score 26.7 episode length  27 average score 33.3 best score:47.7
# episode  1777 score 37.0 episode length  39 average score 33.7 best score:47.7
# episode  1778 score 38.0 episode length  29 average score 34.4 best score:47.7
# episode  1779 score 41.2 episode length  37 average score 34.7 best score:47.7
# episode  1780 score 109.2 episode length  79 average score 35.0 best score:47.7
# episode  1781 score 15.5 episode length  25 average score 33.2 best score:47.7
# episode  1782 score 55.4 episode length  38 average score 33.6 best score:47.7
# episode  1783 score 47.9 episode length  46 average score 34.3 best score:47.7
# episode  1784 score 59.1 episode length  40 average score 34.1 best score:47.7
# episode  1785 score 57.2 episode length  42 average score 34.7 best score:47.7
# episode  1786 score -4.9 episode length  13 average score 34.4 best score:47.7
# episode  1787 score -15.0 episode length  11 average score 34.3 best score:47.7
# episode  1788 score 72.5 episode length  49 average score 34.5 best score:47.7
# episode  1789 score 4.2 episode length  20 average score 34.2 best score:47.7
# episode  1790 score 18.8 episode length  31 average score 34.3 best score:47.7
# episode  1791 score 8.8 episode length  20 average score 33.8 best score:47.7
# episode  1792 score 8.1 episode length  43 average score 33.9 best score:47.7
# episode  1793 score 30.7 episode length  38 average score 33.9 best score:47.7
# episode  1794 score -4.9 episode length  13 average score 33.5 best score:47.7
# episode  1795 score 34.2 episode length  38 average score 33.7 best score:47.7
# episode  1796 score 9.2 episode length  21 average score 33.8 best score:47.7
# episode  1797 score 11.2 episode length  19 average score 33.8 best score:47.7
# episode  1798 score 53.6 episode length  42 average score 34.2 best score:47.7
# episode  1799 score 48.2 episode length  45 average score 33.4 best score:47.7
# episode  1800 score 76.3 episode length  51 average score 34.0 best score:47.7
# episode  1801 score 86.1 episode length  61 average score 35.0 best score:47.7
# episode  1802 score 49.9 episode length  47 average score 35.4 best score:47.7
# episode  1803 score 65.2 episode length  51 average score 36.1 best score:47.7
# episode  1804 score 1.4 episode length  22 average score 36.2 best score:47.7
# episode  1805 score 121.7 episode length  79 average score 37.1 best score:47.7
# episode  1806 score -24.9 episode length  13 average score 36.6 best score:47.7
# episode  1807 score 74.4 episode length  78 average score 37.3 best score:47.7
# episode  1808 score 267.9 episode length  172 average score 39.7 best score:47.7
# episode  1809 score 110.0 episode length  79 average score 40.6 best score:47.7
# episode  1810 score 55.3 episode length  36 average score 40.8 best score:47.7
# episode  1811 score -17.5 episode length  13 average score 40.4 best score:47.7
# episode  1812 score 126.0 episode length  79 average score 41.3 best score:47.7
# episode  1813 score 24.0 episode length  27 average score 40.9 best score:47.7
# episode  1814 score 42.4 episode length  30 average score 41.4 best score:47.7
# episode  1815 score 18.6 episode length  42 average score 41.0 best score:47.7
# episode  1816 score 4.4 episode length  21 average score 40.9 best score:47.7
# episode  1817 score 42.0 episode length  35 average score 39.5 best score:47.7
# episode  1818 score -6.7 episode length  25 average score 39.3 best score:47.7
# episode  1819 score 53.3 episode length  46 average score 39.6 best score:47.7
# episode  1820 score 122.7 episode length  84 average score 40.7 best score:47.7
# episode  1821 score 31.5 episode length  30 average score 40.8 best score:47.7
# episode  1822 score 77.9 episode length  63 average score 40.2 best score:47.7
# episode  1823 score 42.3 episode length  41 average score 40.2 best score:47.7
# episode  1824 score -11.7 episode length  12 average score 39.9 best score:47.7
# episode  1825 score 59.5 episode length  50 average score 40.1 best score:47.7
# episode  1826 score 6.6 episode length  11 average score 40.2 best score:47.7
# episode  1827 score 111.0 episode length  77 average score 40.9 best score:47.7
# episode  1828 score 25.3 episode length  38 average score 40.4 best score:47.7
# episode  1829 score -5.4 episode length  18 average score 40.5 best score:47.7
# episode  1830 score 13.2 episode length  14 average score 41.0 best score:47.7
# episode  1831 score 32.7 episode length  35 average score 41.4 best score:47.7
# episode  1832 score 16.6 episode length  18 average score 39.8 best score:47.7
# episode  1833 score 92.3 episode length  73 average score 40.5 best score:47.7
# episode  1834 score 41.7 episode length  39 average score 41.0 best score:47.7
# episode  1835 score 31.6 episode length  42 average score 40.8 best score:47.7
# episode  1836 score 44.3 episode length  33 average score 40.6 best score:47.7
# episode  1837 score 30.6 episode length  30 average score 40.9 best score:47.7
# episode  1838 score 110.8 episode length  93 average score 41.8 best score:47.7
# episode  1839 score 8.5 episode length  14 average score 41.3 best score:47.7
# episode  1840 score 32.4 episode length  34 average score 41.4 best score:47.7
# episode  1841 score 51.5 episode length  46 average score 41.7 best score:47.7
# ...
# episode  6009 score 26.2 episode length  26 average score 47.6 best score:50.6
# episode  6010 score 7.9 episode length  16 average score 47.3 best score:50.6
# episode  6011 score 73.8 episode length  50 average score 47.7 best score:50.6
# episode  6012 score 5.1 episode length  22 average score 48.0 best score:50.6
# episode  6013 score 108.2 episode length  92 average score 48.6 best score:50.6
# episode  6014 score 58.4 episode length  48 average score 46.3 best score:50.6
# episode  6015 score 4.1 episode length  22 average score 46.2 best score:50.6
# episode  6016 score 36.0 episode length  31 average score 45.9 best score:50.6
# episode  6017 score 0.9 episode length  12 average score 45.0 best score:50.6
# episode  6018 score 41.8 episode length  38 average score 45.0 best score:50.6
# episode  6019 score 8.9 episode length  48 average score 44.9 best score:50.6
# episode  6020 score -6.2 episode length  27 average score 44.4 best score:50.6
# episode  6021 score 117.2 episode length  106 average score 43.6 best score:50.6
# episode  6022 score 38.1 episode length  33 average score 44.0 best score:50.6
# episode  6023 score 27.7 episode length  22 average score 43.4 best score:50.6
# episode  6024 score 16.3 episode length  19 average score 43.4 best score:50.6
# episode  6025 score 129.4 episode length  87 average score 44.3 best score:50.6
# episode  6026 score 37.9 episode length  31 average score 44.2 best score:50.6
# episode  6027 score 88.4 episode length  58 average score 45.0 best score:50.6
# episode  6028 score -7.1 episode length  21 average score 44.1 best score:50.6
# episode  6029 score 22.0 episode length  27 average score 44.1 best score:50.6
# episode  6030 score 21.6 episode length  23 average score 43.4 best score:50.6
# episode  6031 score 35.3 episode length  31 average score 43.7 best score:50.6
# episode  6032 score -14.5 episode length  12 average score 43.5 best score:50.6
# episode  6033 score 75.0 episode length  58 average score 44.2 best score:50.6
# episode  6034 score 25.2 episode length  27 average score 44.4 best score:50.6
# episode  6035 score 7.2 episode length  16 average score 43.6 best score:50.6
# episode  6036 score 4.4 episode length  15 average score 43.0 best score:50.6
# episode  6037 score -39.1 episode length  28 average score 43.0 best score:50.6
# episode  6038 score 48.8 episode length  34 average score 43.5 best score:50.6
# episode  6039 score 39.5 episode length  47 average score 43.7 best score:50.6
# episode  6040 score -8.0 episode length  17 average score 43.4 best score:50.6
# episode  6041 score -5.2 episode length  14 average score 43.0 best score:50.6
# episode  6042 score -11.1 episode length  11 average score 41.9 best score:50.6
# episode  6043 score 84.0 episode length  65 average score 42.2 best score:50.6
# episode  6044 score 59.3 episode length  38 average score 41.8 best score:50.6
# episode  6045 score 23.1 episode length  26 average score 41.2 best score:50.6
# episode  6046 score 241.3 episode length  159 average score 43.4 best score:50.6
# episode  6047 score 24.6 episode length  27 average score 43.7 best score:50.6
# episode  6048 score 24.8 episode length  20 average score 43.8 best score:50.6
# episode  6049 score 52.5 episode length  55 average score 44.5 best score:50.6
# episode  6050 score 33.9 episode length  29 average score 44.4 best score:50.6
# episode  6051 score -3.3 episode length  13 average score 43.6 best score:50.6
# episode  6052 score 16.1 episode length  17 average score 43.6 best score:50.6
# episode  6053 score -9.4 episode length  20 average score 43.3 best score:50.6
# episode  6054 score 84.8 episode length  66 average score 42.6 best score:50.6
# episode  6055 score -4.6 episode length  21 average score 42.0 best score:50.6
# episode  6056 score 35.0 episode length  25 average score 42.2 best score:50.6
# episode  6057 score 166.9 episode length  107 average score 41.9 best score:50.6
# episode  6058 score 47.4 episode length  34 average score 41.2 best score:50.6
# episode  6059 score 74.1 episode length  48 average score 41.6 best score:50.6
# episode  6060 score 32.4 episode length  33 average score 41.0 best score:50.6
# episode  6061 score -21.3 episode length  9 average score 40.5 best score:50.6
# episode  6062 score 55.6 episode length  46 average score 41.1 best score:50.6
# episode  6063 score 24.0 episode length  21 average score 41.2 best score:50.6
# episode  6064 score 78.6 episode length  61 average score 41.2 best score:50.6
# episode  6065 score 8.8 episode length  21 average score 40.6 best score:50.6
# episode  6066 score 40.7 episode length  32 average score 39.5 best score:50.6
# episode  6067 score 26.7 episode length  37 average score 39.7 best score:50.6
# episode  6068 score 15.5 episode length  21 average score 39.5 best score:50.6
# episode  6069 score 40.5 episode length  28 average score 39.7 best score:50.6
# episode  6070 score 23.5 episode length  24 average score 38.9 best score:50.6
# episode  6071 score 103.2 episode length  79 average score 39.7 best score:50.6
# episode  6072 score 4.7 episode length  20 average score 39.6 best score:50.6
# episode  6073 score 152.4 episode length  100 average score 41.0 best score:50.6
# episode  6074 score 72.3 episode length  50 average score 40.9 best score:50.6
# episode  6075 score -9.0 episode length  16 average score 41.0 best score:50.6
# episode  6076 score 123.2 episode length  97 average score 41.9 best score:50.6
# episode  6077 score -6.5 episode length  11 average score 41.8 best score:50.6
# episode  6078 score 119.0 episode length  77 average score 42.7 best score:50.6
# episode  6079 score 13.5 episode length  20 average score 42.7 best score:50.6
# episode  6080 score 9.6 episode length  15 average score 43.1 best score:50.6
# episode  6081 score 22.1 episode length  31 average score 42.6 best score:50.6
# episode  6082 score 58.4 episode length  48 average score 43.0 best score:50.6
# episode  6083 score 54.0 episode length  48 average score 43.2 best score:50.6
# episode  6084 score 51.8 episode length  35 average score 43.8 best score:50.6
# episode  6085 score 59.1 episode length  46 average score 44.4 best score:50.6
# episode  6086 score 88.0 episode length  61 average score 44.8 best score:50.6
# episode  6087 score 14.9 episode length  15 average score 44.8 best score:50.6
# episode  6088 score 57.9 episode length  52 average score 45.1 best score:50.6
# episode  6089 score -36.0 episode length  10 average score 44.2 best score:50.6
# episode  6090 score -0.8 episode length  16 average score 44.0 best score:50.6
# episode  6091 score 22.9 episode length  24 average score 43.5 best score:50.6
# episode  6092 score 81.5 episode length  52 average score 44.0 best score:50.6
# episode  6093 score 1.6 episode length  18 average score 43.8 best score:50.6
# episode  6094 score 37.1 episode length  49 average score 43.9 best score:50.6
# episode  6095 score 14.1 episode length  21 average score 43.9 best score:50.6
# episode  6096 score -14.4 episode length  12 average score 43.6 best score:50.6
# episode  6097 score 9.8 episode length  20 average score 42.4 best score:50.6
# episode  6098 score -2.1 episode length  14 average score 41.1 best score:50.6
# episode  6099 score -6.7 episode length  11 average score 40.8 best score:50.6
# episode  6100 score 157.5 episode length  102 average score 39.1 best score:50.6
# episode  6101 score 32.7 episode length  29 average score 39.4 best score:50.6
# episode  6102 score -1.7 episode length  16 average score 39.0 best score:50.6
# episode  6103 score 40.8 episode length  43 average score 38.6 best score:50.6
# episode  6104 score 16.0 episode length  15 average score 37.6 best score:50.6
# episode  6105 score 54.3 episode length  43 average score 37.8 best score:50.6
# episode  6106 score 54.0 episode length  45 average score 37.3 best score:50.6
# episode  6107 score 13.9 episode length  17 average score 37.4 best score:50.6
# episode  6108 score 8.6 episode length  22 average score 37.6 best score:50.6
# episode  6109 score 36.9 episode length  43 average score 37.7 best score:50.6
# episode  6110 score -5.2 episode length  13 average score 37.6 best score:50.6
# episode  6111 score 54.1 episode length  41 average score 37.4 best score:50.6
# episode  6112 score -0.2 episode length  16 average score 37.3 best score:50.6
# episode  6113 score -5.1 episode length  14 average score 36.2 best score:50.6
# episode  6114 score -0.6 episode length  14 average score 35.6 best score:50.6
# episode  6115 score 17.2 episode length  23 average score 35.7 best score:50.6
# episode  6116 score -36.3 episode length  10 average score 35.0 best score:50.6
# episode  6117 score 15.6 episode length  25 average score 35.2 best score:50.6
# episode  6118 score 39.3 episode length  31 average score 35.1 best score:50.6
# episode  6119 score 72.5 episode length  64 average score 35.8 best score:50.6
# episode  6120 score 27.7 episode length  27 average score 36.1 best score:50.6
# episode  6121 score -15.7 episode length  14 average score 34.8 best score:50.6
# episode  6122 score 22.8 episode length  21 average score 34.6 best score:50.6
# episode  6123 score -0.4 episode length  17 average score 34.4 best score:50.6
# episode  6124 score 29.0 episode length  23 average score 34.5 best score:50.6
# episode  6125 score -1.3 episode length  18 average score 33.2 best score:50.6
# episode  6126 score -17.7 episode length  9 average score 32.6 best score:50.6
# episode  6127 score 5.1 episode length  17 average score 31.8 best score:50.6
# episode  6128 score 120.6 episode length  86 average score 33.1 best score:50.6
# episode  6129 score 15.7 episode length  26 average score 33.0 best score:50.6
# episode  6130 score 19.2 episode length  41 average score 33.0 best score:50.6
# episode  6131 score 72.5 episode length  55 average score 33.4 best score:50.6
# episode  6132 score 9.3 episode length  16 average score 33.6 best score:50.6
# episode  6133 score 83.9 episode length  62 average score 33.7 best score:50.6
# episode  6134 score 6.1 episode length  27 average score 33.5 best score:50.6
# episode  6135 score 86.6 episode length  70 average score 34.3 best score:50.6
# episode  6136 score -0.9 episode length  14 average score 34.2 best score:50.6
# episode  6137 score 13.8 episode length  27 average score 34.8 best score:50.6
# episode  6138 score 12.9 episode length  25 average score 34.4 best score:50.6
# episode  6139 score -44.4 episode length  16 average score 33.6 best score:50.6
# episode  6140 score 63.7 episode length  43 average score 34.3 best score:50.6
# episode  6141 score 62.0 episode length  53 average score 34.9 best score:50.6
# episode  6142 score 18.2 episode length  24 average score 35.2 best score:50.6
# episode  6143 score -14.7 episode length  12 average score 34.3 best score:50.6
# episode  6144 score 0.2 episode length  13 average score 33.7 best score:50.6
# episode  6145 score 41.4 episode length  36 average score 33.8 best score:50.6
# episode  6146 score 19.8 episode length  36 average score 31.6 best score:50.6
# episode  6147 score 78.1 episode length  65 average score 32.2 best score:50.6
# episode  6148 score 105.7 episode length  78 average score 33.0 best score:50.6
# episode  6149 score 109.9 episode length  71 average score 33.5 best score:50.6
# episode  6150 score -25.5 episode length  14 average score 33.0 best score:50.6
# episode  6151 score 10.9 episode length  19 average score 33.1 best score:50.6
# episode  6152 score 43.0 episode length  31 average score 33.4 best score:50.6
# episode  6153 score 16.9 episode length  26 average score 33.6 best score:50.6
# episode  6154 score 19.7 episode length  23 average score 33.0 best score:50.6
# episode  6155 score 107.5 episode length  77 average score 34.1 best score:50.6
# episode  6156 score 20.9 episode length  29 average score 34.0 best score:50.6
# episode  6157 score 12.8 episode length  17 average score 32.4 best score:50.6
# episode  6158 score 113.1 episode length  82 average score 33.1 best score:50.6
# episode  6159 score 16.6 episode length  24 average score 32.5 best score:50.6
# episode  6160 score 29.9 episode length  23 average score 32.5 best score:50.6
# episode  6161 score 65.9 episode length  57 average score 33.3 best score:50.6
# episode  6162 score 72.8 episode length  61 average score 33.5 best score:50.6
# episode  6163 score 15.1 episode length  16 average score 33.4 best score:50.6
# episode  6164 score 61.5 episode length  45 average score 33.3 best score:50.6
# episode  6165 score 68.5 episode length  52 average score 33.9 best score:50.6
# episode  6166 score 23.4 episode length  23 average score 33.7 best score:50.6
# episode  6167 score 25.3 episode length  24 average score 33.7 best score:50.6
# episode  6168 score 28.9 episode length  22 average score 33.8 best score:50.6
# episode  6169 score -24.5 episode length  13 average score 33.2 best score:50.6
# episode  6170 score 124.5 episode length  91 average score 34.2 best score:50.6
# episode  6171 score 17.8 episode length  25 average score 33.3 best score:50.6
# episode  6172 score 42.1 episode length  31 average score 33.7 best score:50.6
# episode  6173 score 14.3 episode length  20 average score 32.3 best score:50.6
# episode  6174 score -4.5 episode length  18 average score 31.5 best score:50.6
# episode  6175 score 45.4 episode length  35 average score 32.1 best score:50.6
# episode  6176 score 54.6 episode length  37 average score 31.4 best score:50.6
# episode  6177 score 68.9 episode length  47 average score 32.1 best score:50.6
# episode  6178 score 65.0 episode length  49 average score 31.6 best score:50.6
# episode  6179 score 44.3 episode length  39 average score 31.9 best score:50.6
# episode  6180 score 11.1 episode length  15 average score 31.9 best score:50.6
# episode  6181 score 41.4 episode length  30 average score 32.1 best score:50.6
# episode  6182 score 20.2 episode length  23 average score 31.7 best score:50.6
# episode  6183 score -0.0 episode length  20 average score 31.2 best score:50.6
# episode  6184 score 40.4 episode length  40 average score 31.1 best score:50.6
# episode  6185 score 66.5 episode length  54 average score 31.2 best score:50.6
# episode  6186 score 23.8 episode length  27 average score 30.5 best score:50.6
# episode  6187 score 5.2 episode length  41 average score 30.4 best score:50.6
# episode  6188 score 61.0 episode length  43 average score 30.5 best score:50.6
# episode  6189 score 7.0 episode length  25 average score 30.9 best score:50.6
# episode  6190 score 55.4 episode length  46 average score 31.4 best score:50.6
# episode  6191 score 32.8 episode length  40 average score 31.5 best score:50.6
# episode  6192 score 127.3 episode length  85 average score 32.0 best score:50.6
# episode  6193 score 0.9 episode length  14 average score 32.0 best score:50.6
# episode  6194 score -4.8 episode length  10 average score 31.6 best score:50.6
# episode  6195 score 34.9 episode length  33 average score 31.8 best score:50.6
# episode  6196 score 32.3 episode length  26 average score 32.3 best score:50.6
# episode  6197 score 39.6 episode length  39 average score 32.5 best score:50.6
# episode  6198 score -1.6 episode length  14 average score 32.6 best score:50.6
# episode  6199 score 18.8 episode length  31 average score 32.8 best score:50.6
# episode  6200 score 73.4 episode length  59 average score 32.0 best score:50.6
# episode  6201 score -13.5 episode length  22 average score 31.5 best score:50.6
# episode  6202 score 5.8 episode length  15 average score 31.6 best score:50.6
# episode  6203 score 42.6 episode length  37 average score 31.6 best score:50.6
# episode  6204 score 92.4 episode length  64 average score 32.4 best score:50.6
# episode  6205 score 91.9 episode length  60 average score 32.7 best score:50.6
# episode  6206 score 157.9 episode length  102 average score 33.8 best score:50.6
# episode  6207 score 38.2 episode length  36 average score 34.0 best score:50.6
# episode  6208 score 2.1 episode length  15 average score 34.0 best score:50.6
# episode  6209 score 73.2 episode length  49 average score 34.3 best score:50.6
# episode  6210 score 10.7 episode length  17 average score 34.5 best score:50.6

# %%
print(best_score_list)
print(max)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1f26297ed5a1> in <module>()
# ----> 1 print(best_score_list)
#       2 print(max)
#
# NameError: name 'best_score_list' is not defined

# %%
env = gym.make('CartPole-v1')
n_games = 1200
n_steps=400

score_history = []
score_action_history = []
prev_screen = env.render(mode='rgb_array')
# print(prev_screen)

# %%
# env = CartPoleEnv(use_theta_threshold=True)
env = gym.make('CartPole-v1')
n_games = 1200

n_steps=400

score_history = []
score_action_history = []
env.reset()
prev_screen = env.render(mode='rgb_array')
plt.imshow(prev_screen)

for i in range(n_games):
    observation = env.reset()
    
    done = False
    score = 0
    k=0
    while not done:
        screen = env.render(mode='rgb_array')
        k+=1
        
        action = np.dot(K,observation)[0,0]
        observation_, reward, done, info = env.step_force(action)
        score += reward
        observation = observation_

        plt.imshow(screen)
        ipythondisplay.clear_output(wait=True)
        ipythondisplay.display(plt.gcf())

        if k>n_steps:
            done=True
    
        
    
    score_history.append(score)
    score_action_history.append(score/k)
    
    avg_score = np.mean(score_history[-100:])
    avg_action_score = np.mean(score_action_history[-100:])

    
    print('episode ', i, 'score %.1f' % score_action_history[-1],'episode length ',k,
            'average score %.1f' % avg_action_score)
ipythondisplay.clear_output(wait=True)
env.close()
# env.close() 
print('mean action reward %.1f' % np.mean(score_action_history))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-069ded5dc37c> in <module>()
#       8 score_action_history = []
#       9 env.reset()
# ---> 10 prev_screen = env.render(mode='rgb_array')
#      11 plt.imshow(prev_screen)
#      12
#
# /usr/local/lib/python3.7/dist-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/classic_control/cartpole.py in render(self, mode)
#     172
#     173         if self.viewer is None:
# --> 174             from gym.envs.classic_control import rendering
#     175             self.viewer = rendering.Viewer(screen_width, screen_height)
#     176             l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/classic_control/rendering.py in <module>()
#      23
#      24 try:
# ---> 25     from pyglet.gl import *
#      26 except ImportError as e:
#      27     raise ImportError('''
#
# /usr/local/lib/python3.7/dist-packages/pyglet/gl/__init__.py in <module>()
#     233 elif compat_platform == 'darwin':
#     234     from .cocoa import CocoaConfig as Config
# --> 235 del base  # noqa: F821
#     236
#     237
#
# NameError: name 'base' is not defined

# %% [markdown]
# # Inspecting results

# %%
env = CartPoleEnv(use_theta_threshold=True)
# env = gym.make('LunarLanderContinuous-v2')
agent = Agent(alpha=0.0001, beta=0.001, 
                input_dims=env.observation_space.shape, output_bounds=30,
                tau=0.001,
                batch_size=64, fc1_dims=400, fc2_dims=300, 
                n_actions=1)
agent.load_models()
# Out:
# ... loading checkpoint ...
# ... loading checkpoint ...
# ... loading checkpoint ...
# ... loading checkpoint ...

# %%
observation = env.reset()
# print(observation.shape)
# print(observation)
done = False
score = 0
agent.noise.reset()
k=0
n_steps=400
while not done:
    k+=1
    
    action = agent.choose_action_no_noise(observation)[0]

    observation_, reward, done, info = env.step_force(action)

    agent.remember(observation, action, reward, observation_, done)
    # agent.learn()

    score += reward
    observation = observation_
    if k>n_steps:
        done=True

print(score)
# Out:
# 405.00974916858075
